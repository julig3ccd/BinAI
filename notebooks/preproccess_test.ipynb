# %%
import sys
sys.path.append('..')  # Add parent directory

from utils.pre_proccess_util import PreProcessor

processor = PreProcessor()

# %%
processor.process_binary_dataset()
# Out:
# creating angr project for ../data/Dataset-1-X64/openssl/x64-clang-3.5-O0_libcrypto.so.3
# analysing cfg...
# took 24.184703826904297 seconds to analyse cfg
# getting asm...
# took 6.647059202194214 seconds to get asm
# took 31.810314893722534 seconds to process "x64-clang-3.5-O0_libcrypto.so.3" with storage :defaultdict(<class 'list'>, {})
# {'compiler': 'clang-3.5',
#  'optimization': 'O0',
#  'project': 'libcrypto.so.3',
#  'asm': [{'func_name': '_init',
#    'func_instr': {'1': 'sub rsp, 8',
#     '2': 'mov rax, qword ptr [rip + 0x59318d]',
#     '3': 'test rax, rax',
#     '4': 'je 0x492e2a',
#     '5': 'call rax',
#     '6': 'call 0x61b7e0',
#     '7': 'add rsp, 8',
#     '8': 'ret '}},
#   {'func_name': 'pthread_getspecific',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5931a2]'}},
#   {'func_name': 'memset',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59319a]'}},
#   {'func_name': 'ftell',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593192]'}},
#   {'func_name': 'shutdown',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59318a]'}},
#   {'func_name': 'getauxval',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593182]'}},
#   {'func_name': 'close',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59317a]'}},
#   {'func_name': 'syslog',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593172]'}},
#   {'func_name': 'ioctl',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59316a]'}},
#   {'func_name': 'shmdt',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593162]'}},
#   {'func_name': 'abort',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59315a]'}},
#   {'func_name': 'pthread_setspecific',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593152]'}},
#   {'func_name': 'memchr',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593142]'}},
#   {'func_name': 'clock_gettime',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59313a]'}},
#   {'func_name': 'gethostbyname',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593132]'}},
#   {'func_name': '_setjmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593122]'}},
#   {'func_name': 'fseek',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59311a]'}},
#   {'func_name': '__isoc99_sscanf',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59310a]'}},
#   {'func_name': 'openlog',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930fa]'}},
#   {'func_name': 'gettimeofday',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930ea]'}},
#   {'func_name': 'setcontext',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930da]'}},
#   {'func_name': '__register_atfork',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930d2]'}},
#   {'func_name': 'read', 'func_instr': {'1': 'jmp qword ptr [rip + 0x5930ca]'}},
#   {'func_name': 'strncmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930c2]'}},
#   {'func_name': 'malloc',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930ba]'}},
#   {'func_name': '_longjmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930aa]'}},
#   {'func_name': 'pthread_rwlock_destroy',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x5930a2]'}},
#   {'func_name': '__cxa_atexit',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59309a]'}},
#   {'func_name': 'setsockopt',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593092]'}},
#   {'func_name': 'getpid',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593082]'}},
#   {'func_name': 'fgets',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59307a]'}},
#   {'func_name': 'vfprintf',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593072]'}},
#   {'func_name': 'closelog',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59306a]'}},
#   {'func_name': 'freeaddrinfo',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593062]'}},
#   {'func_name': 'free', 'func_instr': {'1': 'jmp qword ptr [rip + 0x59305a]'}},
#   {'func_name': 'secure_getenv',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593052]'}},
#   {'func_name': 'strlen',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59304a]'}},
#   {'func_name': '__xstat',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593032]'}},
#   {'func_name': '__ctype_b_loc',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x593022]'}},
#   {'func_name': 'pthread_key_delete',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59301a]'}},
#   {'func_name': 'ntohs',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592ffa]'}},
#   {'func_name': 'strrchr',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fea]'}},
#   {'func_name': 'syscall',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fe2]'}},
#   {'func_name': 'dlclose',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fda]'}},
#   {'func_name': 'pthread_self',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fd2]'}},
#   {'func_name': 'gmtime_r',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fca]'}},
#   {'func_name': 'sigaction',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fba]'}},
#   {'func_name': 'getsockopt',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592fa2]'}},
#   {'func_name': 'fputs',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f9a]'}},
#   {'func_name': 'lseek',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f92]'}},
#   {'func_name': 'strtol',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f8a]'}},
#   {'func_name': 'getsockname',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f82]'}},
#   {'func_name': 'connect',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f72]'}},
#   {'func_name': 'pthread_rwlock_init',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f62]'}},
#   {'func_name': 'memmove',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f42]'}},
#   {'func_name': 'strchr',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f3a]'}},
#   {'func_name': 'socket',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f32]'}},
#   {'func_name': 'fread',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f2a]'}},
#   {'func_name': '__fxstat',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f22]'}},
#   {'func_name': 'getenv',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f1a]'}},
#   {'func_name': '__errno_location',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f12]'}},
#   {'func_name': 'pthread_equal',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f0a]'}},
#   {'func_name': 'qsort',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592f02]'}},
#   {'func_name': 'strdup',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592ef2]'}},
#   {'func_name': 'strncasecmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592eea]'}},
#   {'func_name': 'strcpy',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592eda]'}},
#   {'func_name': 'pthread_rwlock_rdlock',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592ed2]'}},
#   {'func_name': 'dladdr',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592eca]'}},
#   {'func_name': 'pthread_once',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592ec2]'}},
#   {'func_name': 'memcmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592eba]'}},
#   {'func_name': 'getcontext',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592eb2]'}},
#   {'func_name': '__xpg_strerror_r',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592ea2]'}},
#   {'func_name': 'shmget',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e9a]'}},
#   {'func_name': 'fclose',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e8a]'}},
#   {'func_name': 'dlopen',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e82]'}},
#   {'func_name': 'pthread_rwlock_wrlock',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e7a]'}},
#   {'func_name': 'strncpy',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e6a]'}},
#   {'func_name': 'dlsym',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e62]'}},
#   {'func_name': 'closedir',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e5a]'}},
#   {'func_name': 'fopen64',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e42]'}},
#   {'func_name': 'bind', 'func_instr': {'1': 'jmp qword ptr [rip + 0x592e32]'}},
#   {'func_name': 'fwrite',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e2a]'}},
#   {'func_name': 'pthread_rwlock_unlock',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e22]'}},
#   {'func_name': 'htonl',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e1a]'}},
#   {'func_name': 'realloc',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592e12]'}},
#   {'func_name': 'pthread_key_create',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592dfa]'}},
#   {'func_name': 'fprintf',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592df2]'}},
#   {'func_name': 'accept',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592de2]'}},
#   {'func_name': 'strtoul',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592dda]'}},
#   {'func_name': 'memcpy',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592dd2]'}},
#   {'func_name': 'open', 'func_instr': {'1': 'jmp qword ptr [rip + 0x592dca]'}},
#   {'func_name': 'time', 'func_instr': {'1': 'jmp qword ptr [rip + 0x592dba]'}},
#   {'func_name': 'strcasecmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592912]'}},
#   {'func_name': 'getentropy',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592922]'}},
#   {'func_name': '__cxa_finalize',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x592922]'}},
#   {'func_name': 'strcmp',
#    'func_instr': {'1': 'jmp qword ptr [rip + 0x59292a]'}},
#   {'func_name': 'deregister_tm_clones',
#    'func_instr': {'1': 'lea rdi, [rip + 0x594741]',
#     '2': 'push rbp',
#     '3': 'lea rax, [rip + 0x594739]',
#     '4': 'cmp rax, rdi',
#     '5': 'mov rbp, rsp',
#     '6': 'je 0x494030',
#     '7': 'mov rax, qword ptr [rip + 0x591fa2]',
#     '8': 'test rax, rax',
#     '9': 'je 0x494030',
#     '10': 'pop rbp',
#     '11': 'jmp rax',
#     '12': 'pop rbp',
#     '13': 'ret '}},
#   {'func_name': 'register_tm_clones',
#    'func_instr': {'1': 'lea rdi, [rip + 0x594701]',
#     '2': 'lea rsi, [rip + 0x5946fa]',
#     '3': 'push rbp',
#     '4': 'sub rsi, rdi',
#     '5': 'mov rbp, rsp',
#     '6': 'sar rsi, 3',
#     '7': 'mov rax, rsi',
#     '8': 'shr rax, 0x3f',
#     '9': 'add rsi, rax',
#     '10': 'sar rsi, 1',
#     '11': 'je 0x494080',
#     '12': 'mov rax, qword ptr [rip + 0x591f59]',
#     '13': 'test rax, rax',
#     '14': 'je 0x494080',
#     '15': 'pop rbp',
#     '16': 'jmp rax',
#     '17': 'pop rbp',
#     '18': 'ret '}},
#   {'func_name': '__do_global_dtors_aux',
#    'func_instr': {'1': 'cmp byte ptr [rip + 0x5946b9], 0',
#     '2': 'jne 0x4940c8',
#     '3': 'cmp qword ptr [rip + 0x591f37], 0',
#     '4': 'push rbp',
#     '5': 'mov rbp, rsp',
#     '6': 'je 0x4940b3',
#     '7': 'mov rdi, qword ptr [rip + 0x592392]',
#     '8': 'call 0x4936b0',
#     '9': 'call 0x494000',
#     '10': 'mov byte ptr [rip + 0x594691], 1',
#     '11': 'pop rbp',
#     '12': 'ret ',
#     '13': 'repz ret '}},
#   {'func_name': 'frame_dummy',
#    'func_instr': {'1': 'push rbp',
#     '2': 'mov rbp, rsp',
#     '3': 'pop rbp',
#     '4': 'jmp 0x494040'}},
#   {'func_name': '_x86_64_AES_encrypt',
#    'func_instr': {'1': 'xor eax, dword ptr [r15]',
#     '2': 'xor ebx, dword ptr [r15 + 4]',
#     '3': 'xor ecx, dword ptr [r15 + 8]',
#     '4': 'xor edx, dword ptr [r15 + 0xc]',
#     '5': 'mov r13d, dword ptr [r15 + 0xf0]',
#     '6': 'sub r13d, 1',
#     '7': 'jmp 0x494120',
#     '8': 'movzx esi, al',
#     '9': 'movzx edi, bl',
#     '10': 'movzx ebp, cl',
#     '11': 'mov r10d, dword ptr [r14 + rsi*8]',
#     '12': 'mov r11d, dword ptr [r14 + rdi*8]',
#     '13': 'mov r12d, dword ptr [r14 + rbp*8]',
#     '14': 'movzx esi, bh',
#     '15': 'movzx edi, ch',
#     '16': 'movzx ebp, dl',
#     '17': 'xor r10d, dword ptr [r14 + rsi*8 + 3]',
#     '18': 'xor r11d, dword ptr [r14 + rdi*8 + 3]',
#     '19': 'mov r8d, dword ptr [r14 + rbp*8]',
#     '20': 'movzx esi, dh',
#     '21': 'shr ecx, 0x10',
#     '22': 'movzx ebp, ah',
#     '23': 'xor r12d, dword ptr [r14 + rsi*8 + 3]',
#     '24': 'shr edx, 0x10',
#     '25': 'xor r8d, dword ptr [r14 + rbp*8 + 3]',
#     '26': 'shr ebx, 0x10',
#     '27': 'lea r15, [r15 + 0x10]',
#     '28': 'shr eax, 0x10',
#     '29': 'movzx esi, cl',
#     '30': 'movzx edi, dl',
#     '31': 'movzx ebp, al',
#     '32': 'xor r10d, dword ptr [r14 + rsi*8 + 2]',
#     '33': 'xor r11d, dword ptr [r14 + rdi*8 + 2]',
#     '34': 'xor r12d, dword ptr [r14 + rbp*8 + 2]',
#     '35': 'movzx esi, dh',
#     '36': 'movzx edi, ah',
#     '37': 'movzx ebp, bl',
#     '38': 'xor r10d, dword ptr [r14 + rsi*8 + 1]',
#     '39': 'xor r11d, dword ptr [r14 + rdi*8 + 1]',
#     '40': 'xor r8d, dword ptr [r14 + rbp*8 + 2]',
#     '41': 'mov edx, dword ptr [r15 + 0xc]',
#     '42': 'movzx edi, bh',
#     '43': 'movzx ebp, ch',
#     '44': 'mov eax, dword ptr [r15]',
#     '45': 'xor r12d, dword ptr [r14 + rdi*8 + 1]',
#     '46': 'xor r8d, dword ptr [r14 + rbp*8 + 1]',
#     '47': 'mov ebx, dword ptr [r15 + 4]',
#     '48': 'mov ecx, dword ptr [r15 + 8]',
#     '49': 'xor eax, r10d',
#     '50': 'xor ebx, r11d',
#     '51': 'xor ecx, r12d',
#     '52': 'xor edx, r8d',
#     '53': 'sub r13d, 1',
#     '54': 'jne 0x494120',
#     '55': 'movzx esi, al',
#     '56': 'movzx edi, bl',
#     '57': 'movzx ebp, cl',
#     '58': 'movzx r10d, byte ptr [r14 + rsi*8 + 2]',
#     '59': 'movzx r11d, byte ptr [r14 + rdi*8 + 2]',
#     '60': 'movzx r12d, byte ptr [r14 + rbp*8 + 2]',
#     '61': 'movzx esi, dl',
#     '62': 'movzx edi, bh',
#     '63': 'movzx ebp, ch',
#     '64': 'movzx r8d, byte ptr [r14 + rsi*8 + 2]',
#     '65': 'mov edi, dword ptr [r14 + rdi*8]',
#     '66': 'mov ebp, dword ptr [r14 + rbp*8]',
#     '67': 'and edi, 0xff00',
#     '68': 'and ebp, 0xff00',
#     '69': 'xor r10d, edi',
#     '70': 'xor r11d, ebp',
#     '71': 'shr ecx, 0x10',
#     '72': 'movzx esi, dh',
#     '73': 'movzx edi, ah',
#     '74': 'shr edx, 0x10',
#     '75': 'mov esi, dword ptr [r14 + rsi*8]',
#     '76': 'mov edi, dword ptr [r14 + rdi*8]',
#     '77': 'and esi, 0xff00',
#     '78': 'and edi, 0xff00',
#     '79': 'shr ebx, 0x10',
#     '80': 'xor r12d, esi',
#     '81': 'xor r8d, edi',
#     '82': 'shr eax, 0x10',
#     '83': 'movzx esi, cl',
#     '84': 'movzx edi, dl',
#     '85': 'movzx ebp, al',
#     '86': 'mov esi, dword ptr [r14 + rsi*8]',
#     '87': 'mov edi, dword ptr [r14 + rdi*8]',
#     '88': 'mov ebp, dword ptr [r14 + rbp*8]',
#     '89': 'and esi, 0xff0000',
#     '90': 'and edi, 0xff0000',
#     '91': 'and ebp, 0xff0000',
#     '92': 'xor r10d, esi',
#     '93': 'xor r11d, edi',
#     '94': 'xor r12d, ebp',
#     '95': 'movzx esi, bl',
#     '96': 'movzx edi, dh',
#     '97': 'movzx ebp, ah',
#     '98': 'mov esi, dword ptr [r14 + rsi*8]',
#     '99': 'mov edi, dword ptr [r14 + rdi*8 + 2]',
#     '100': 'mov ebp, dword ptr [r14 + rbp*8 + 2]',
#     '101': 'and esi, 0xff0000',
#     '102': 'and edi, 0xff000000',
#     '103': 'and ebp, 0xff000000',
#     '104': 'xor r8d, esi',
#     '105': 'xor r10d, edi',
#     '106': 'xor r11d, ebp',
#     '107': 'movzx esi, bh',
#     '108': 'movzx edi, ch',
#     '109': 'mov edx, dword ptr [r15 + 0x1c]',
#     '110': 'mov esi, dword ptr [r14 + rsi*8 + 2]',
#     '111': 'mov edi, dword ptr [r14 + rdi*8 + 2]',
#     '112': 'mov eax, dword ptr [r15 + 0x10]',
#     '113': 'and esi, 0xff000000',
#     '114': 'and edi, 0xff000000',
#     '115': 'xor r12d, esi',
#     '116': 'xor r8d, edi',
#     '117': 'mov ebx, dword ptr [r15 + 0x14]',
#     '118': 'mov ecx, dword ptr [r15 + 0x18]',
#     '119': 'xor eax, r10d',
#     '120': 'xor ebx, r11d',
#     '121': 'xor ecx, r12d',
#     '122': 'xor edx, r8d',
#     '123': 'repz ret '}},
#   {'func_name': '_x86_64_AES_encrypt_compact',
#    'func_instr': {'1': 'lea r8, [r14 + 0x80]',
#     '2': 'mov edi, dword ptr [r8 - 0x80]',
#     '3': 'mov ebp, dword ptr [r8 - 0x60]',
#     '4': 'mov r10d, dword ptr [r8 - 0x40]',
#     '5': 'mov r11d, dword ptr [r8 - 0x20]',
#     '6': 'mov edi, dword ptr [r8]',
#     '7': 'mov ebp, dword ptr [r8 + 0x20]',
#     '8': 'mov r10d, dword ptr [r8 + 0x40]',
#     '9': 'mov r11d, dword ptr [r8 + 0x60]',
#     '10': 'jmp 0x494320',
#     '11': 'xor eax, dword ptr [r15]',
#     '12': 'xor ebx, dword ptr [r15 + 4]',
#     '13': 'xor ecx, dword ptr [r15 + 8]',
#     '14': 'xor edx, dword ptr [r15 + 0xc]',
#     '15': 'lea r15, [r15 + 0x10]',
#     '16': 'movzx r10d, al',
#     '17': 'movzx r11d, bl',
#     '18': 'movzx r12d, cl',
#     '19': 'movzx r8d, dl',
#     '20': 'movzx esi, bh',
#     '21': 'movzx edi, ch',
#     '22': 'shr ecx, 0x10',
#     '23': 'movzx ebp, dh',
#     '24': 'movzx r10d, byte ptr [r14 + r10]',
#     '25': 'movzx r11d, byte ptr [r14 + r11]',
#     '26': 'movzx r12d, byte ptr [r14 + r12]',
#     '27': 'movzx r8d, byte ptr [r14 + r8]',
#     '28': 'movzx r9d, byte ptr [r14 + rsi]',
#     '29': 'movzx esi, ah',
#     '30': 'movzx r13d, byte ptr [r14 + rdi]',
#     '31': 'movzx edi, cl',
#     '32': 'movzx ebp, byte ptr [r14 + rbp]',
#     '33': 'movzx esi, byte ptr [r14 + rsi]',
#     '34': 'shl r9d, 8',
#     '35': 'shr edx, 0x10',
#     '36': 'shl r13d, 8',
#     '37': 'xor r10d, r9d',
#     '38': 'shr eax, 0x10',
#     '39': 'movzx r9d, dl',
#     '40': 'shr ebx, 0x10',
#     '41': 'xor r11d, r13d',
#     '42': 'shl ebp, 8',
#     '43': 'movzx r13d, al',
#     '44': 'movzx edi, byte ptr [r14 + rdi]',
#     '45': 'xor r12d, ebp',
#     '46': 'shl esi, 8',
#     '47': 'movzx ebp, bl',
#     '48': 'shl edi, 0x10',
#     '49': 'xor r8d, esi',
#     '50': 'movzx r9d, byte ptr [r14 + r9]',
#     '51': 'movzx esi, dh',
#     '52': 'movzx r13d, byte ptr [r14 + r13]',
#     '53': 'xor r10d, edi',
#     '54': 'shr ecx, 8',
#     '55': 'movzx edi, ah',
#     '56': 'shl r9d, 0x10',
#     '57': 'shr ebx, 8',
#     '58': 'shl r13d, 0x10',
#     '59': 'xor r11d, r9d',
#     '60': 'movzx ebp, byte ptr [r14 + rbp]',
#     '61': 'movzx esi, byte ptr [r14 + rsi]',
#     '62': 'movzx edi, byte ptr [r14 + rdi]',
#     '63': 'movzx edx, byte ptr [r14 + rcx]',
#     '64': 'movzx ecx, byte ptr [r14 + rbx]',
#     '65': 'shl ebp, 0x10',
#     '66': 'xor r12d, r13d',
#     '67': 'shl esi, 0x18',
#     '68': 'xor r8d, ebp',
#     '69': 'shl edi, 0x18',
#     '70': 'xor r10d, esi',
#     '71': 'shl edx, 0x18',
#     '72': 'xor r11d, edi',
#     '73': 'shl ecx, 0x18',
#     '74': 'mov eax, r10d',
#     '75': 'mov ebx, r11d',
#     '76': 'xor ecx, r12d',
#     '77': 'xor edx, r8d',
#     '78': 'cmp r15, qword ptr [rsp + 0x10]',
#     '79': 'je 0x494540',
#     '80': 'mov r10d, 0x80808080',
#     '81': 'mov r11d, 0x80808080',
#     '82': 'and r10d, eax',
#     '83': 'and r11d, ebx',
#     '84': 'mov esi, r10d',
#     '85': 'mov edi, r11d',
#     '86': 'shr r10d, 7',
#     '87': 'lea r8d, [rax + rax]',
#     '88': 'shr r11d, 7',
#     '89': 'lea r9d, [rbx + rbx]',
#     '90': 'sub esi, r10d',
#     '91': 'sub edi, r11d',
#     '92': 'and r8d, 0xfefefefe',
#     '93': 'and r9d, 0xfefefefe',
#     '94': 'and esi, 0x1b1b1b1b',
#     '95': 'and edi, 0x1b1b1b1b',
#     '96': 'mov r10d, eax',
#     '97': 'mov r11d, ebx',
#     '98': 'xor r8d, esi',
#     '99': 'xor r9d, edi',
#     '100': 'xor eax, r8d',
#     '101': 'xor ebx, r9d',
#     '102': 'mov r12d, 0x80808080',
#     '103': 'rol eax, 0x18',
#     '104': 'mov ebp, 0x80808080',
#     '105': 'rol ebx, 0x18',
#     '106': 'and r12d, ecx',
#     '107': 'and ebp, edx',
#     '108': 'xor eax, r8d',
#     '109': 'xor ebx, r9d',
#     '110': 'mov esi, r12d',
#     '111': 'ror r10d, 0x10',
#     '112': 'mov edi, ebp',
#     '113': 'ror r11d, 0x10',
#     '114': 'lea r8d, [rcx + rcx]',
#     '115': 'shr r12d, 7',
#     '116': 'xor eax, r10d',
#     '117': 'shr ebp, 7',
#     '118': 'xor ebx, r11d',
#     '119': 'ror r10d, 8',
#     '120': 'lea r9d, [rdx + rdx]',
#     '121': 'ror r11d, 8',
#     '122': 'sub esi, r12d',
#     '123': 'sub edi, ebp',
#     '124': 'xor eax, r10d',
#     '125': 'xor ebx, r11d',
#     '126': 'and r8d, 0xfefefefe',
#     '127': 'and r9d, 0xfefefefe',
#     '128': 'and esi, 0x1b1b1b1b',
#     '129': 'and edi, 0x1b1b1b1b',
#     '130': 'mov r12d, ecx',
#     '131': 'mov ebp, edx',
#     '132': 'xor r8d, esi',
#     '133': 'xor r9d, edi',
#     '134': 'ror r12d, 0x10',
#     '135': 'xor ecx, r8d',
#     '136': 'ror ebp, 0x10',
#     '137': 'xor edx, r9d',
#     '138': 'rol ecx, 0x18',
#     '139': 'mov esi, dword ptr [r14]',
#     '140': 'rol edx, 0x18',
#     '141': 'xor ecx, r8d',
#     '142': 'mov edi, dword ptr [r14 + 0x40]',
#     '143': 'xor edx, r9d',
#     '144': 'mov r8d, dword ptr [r14 + 0x80]',
#     '145': 'xor ecx, r12d',
#     '146': 'ror r12d, 8',
#     '147': 'xor edx, ebp',
#     '148': 'ror ebp, 8',
#     '149': 'xor ecx, r12d',
#     '150': 'mov r9d, dword ptr [r14 + 0xc0]',
#     '151': 'xor edx, ebp',
#     '152': 'jmp 0x494320',
#     '153': 'xor eax, dword ptr [r15]',
#     '154': 'xor ebx, dword ptr [r15 + 4]',
#     '155': 'xor ecx, dword ptr [r15 + 8]',
#     '156': 'xor edx, dword ptr [r15 + 0xc]',
#     '157': 'repz ret '}},
#   {'func_name': 'AES_encrypt',
#    'func_instr': {'1': 'mov rax, rsp',
#     '2': 'push rbx',
#     '3': 'push rbp',
#     '4': 'push r12',
#     '5': 'push r13',
#     '6': 'push r14',
#     '7': 'push r15',
#     '8': 'lea rcx, [rdx - 0x3f]',
#     '9': 'and rsp, 0xffffffffffffffc0',
#     '10': 'sub rcx, rsp',
#     '11': 'neg rcx',
#     '12': 'and rcx, 0x3c0',
#     '13': 'sub rsp, rcx',
#     '14': 'sub rsp, 0x20',
#     '15': 'mov qword ptr [rsp + 0x10], rsi',
#     '16': 'mov qword ptr [rsp + 0x18], rax',
#     '17': 'mov r15, rdx',
#     '18': 'mov r13d, dword ptr [r15 + 0xf0]',
#     '19': 'mov eax, dword ptr [rdi]',
#     '20': 'mov ebx, dword ptr [rdi + 4]',
#     '21': 'mov ecx, dword ptr [rdi + 8]',
#     '22': 'mov edx, dword ptr [rdi + 0xc]',
#     '23': 'shl r13d, 4',
#     '24': 'lea rbp, [r15 + r13]',
#     '25': 'mov qword ptr [rsp], r15',
#     '26': 'mov qword ptr [rsp + 8], rbp',
#     '27': 'lea r14, [rip + 0x1880]',
#     '28': 'lea rbp, [rsp + 0x300]',
#     '29': 'sub rbp, r14',
#     '30': 'and rbp, 0x300',
#     '31': 'lea r14, [r14 + rbp]',
#     '32': 'call 0x4942f0',
#     '33': 'mov r9, qword ptr [rsp + 0x10]',
#     '34': 'mov rsi, qword ptr [rsp + 0x18]',
#     '35': 'mov dword ptr [r9], eax',
#     '36': 'mov dword ptr [r9 + 4], ebx',
#     '37': 'mov dword ptr [r9 + 8], ecx',
#     '38': 'mov dword ptr [r9 + 0xc], edx',
#     '39': 'mov r15, qword ptr [rsi - 0x30]',
#     '40': 'mov r14, qword ptr [rsi - 0x28]',
#     '41': 'mov r13, qword ptr [rsi - 0x20]',
#     '42': 'mov r12, qword ptr [rsi - 0x18]',
#     '43': 'mov rbp, qword ptr [rsi - 0x10]',
#     '44': 'mov rbx, qword ptr [rsi - 8]',
#     '45': 'lea rsp, [rsi]',
#     '46': 'repz ret '}},
#   {'func_name': '_x86_64_AES_decrypt',
#    'func_instr': {'1': 'xor eax, dword ptr [r15]',
#     '2': 'xor ebx, dword ptr [r15 + 4]',
#     '3': 'xor ecx, dword ptr [r15 + 8]',
#     '4': 'xor edx, dword ptr [r15 + 0xc]',
#     '5': 'mov r13d, dword ptr [r15 + 0xf0]',
#     '6': 'sub r13d, 1',
#     '7': 'jmp 0x494640',
#     '8': 'movzx esi, al',
#     '9': 'movzx edi, bl',
#     '10': 'movzx ebp, cl',
#     '11': 'mov r10d, dword ptr [r14 + rsi*8]',
#     '12': 'mov r11d, dword ptr [r14 + rdi*8]',
#     '13': 'mov r12d, dword ptr [r14 + rbp*8]',
#     '14': 'movzx esi, dh',
#     '15': 'movzx edi, ah',
#     '16': 'movzx ebp, dl',
#     '17': 'xor r10d, dword ptr [r14 + rsi*8 + 3]',
#     '18': 'xor r11d, dword ptr [r14 + rdi*8 + 3]',
#     '19': 'mov r8d, dword ptr [r14 + rbp*8]',
#     '20': 'movzx esi, bh',
#     '21': 'shr eax, 0x10',
#     '22': 'movzx ebp, ch',
#     '23': 'xor r12d, dword ptr [r14 + rsi*8 + 3]',
#     '24': 'shr edx, 0x10',
#     '25': 'xor r8d, dword ptr [r14 + rbp*8 + 3]',
#     '26': 'shr ebx, 0x10',
#     '27': 'lea r15, [r15 + 0x10]',
#     '28': 'shr ecx, 0x10',
#     '29': 'movzx esi, cl',
#     '30': 'movzx edi, dl',
#     '31': 'movzx ebp, al',
#     '32': 'xor r10d, dword ptr [r14 + rsi*8 + 2]',
#     '33': 'xor r11d, dword ptr [r14 + rdi*8 + 2]',
#     '34': 'xor r12d, dword ptr [r14 + rbp*8 + 2]',
#     '35': 'movzx esi, bh',
#     '36': 'movzx edi, ch',
#     '37': 'movzx ebp, bl',
#     '38': 'xor r10d, dword ptr [r14 + rsi*8 + 1]',
#     '39': 'xor r11d, dword ptr [r14 + rdi*8 + 1]',
#     '40': 'xor r8d, dword ptr [r14 + rbp*8 + 2]',
#     '41': 'movzx esi, dh',
#     '42': 'mov edx, dword ptr [r15 + 0xc]',
#     '43': 'movzx ebp, ah',
#     '44': 'xor r12d, dword ptr [r14 + rsi*8 + 1]',
#     '45': 'mov eax, dword ptr [r15]',
#     '46': 'xor r8d, dword ptr [r14 + rbp*8 + 1]',
#     '47': 'xor eax, r10d',
#     '48': 'mov ebx, dword ptr [r15 + 4]',
#     '49': 'mov ecx, dword ptr [r15 + 8]',
#     '50': 'xor ecx, r12d',
#     '51': 'xor ebx, r11d',
#     '52': 'xor edx, r8d',
#     '53': 'sub r13d, 1',
#     '54': 'jne 0x494640',
#     '55': 'lea r14, [r14 + 0x800]',
#     '56': 'movzx esi, al',
#     '57': 'movzx edi, bl',
#     '58': 'movzx ebp, cl',
#     '59': 'movzx r10d, byte ptr [r14 + rsi]',
#     '60': 'movzx r11d, byte ptr [r14 + rdi]',
#     '61': 'movzx r12d, byte ptr [r14 + rbp]',
#     '62': 'movzx esi, dl',
#     '63': 'movzx edi, dh',
#     '64': 'movzx ebp, ah',
#     '65': 'movzx r8d, byte ptr [r14 + rsi]',
#     '66': 'movzx edi, byte ptr [r14 + rdi]',
#     '67': 'movzx ebp, byte ptr [r14 + rbp]',
#     '68': 'shl edi, 8',
#     '69': 'shl ebp, 8',
#     '70': 'xor r10d, edi',
#     '71': 'xor r11d, ebp',
#     '72': 'shr edx, 0x10',
#     '73': 'movzx esi, bh',
#     '74': 'movzx edi, ch',
#     '75': 'shr eax, 0x10',
#     '76': 'movzx esi, byte ptr [r14 + rsi]',
#     '77': 'movzx edi, byte ptr [r14 + rdi]',
#     '78': 'shl esi, 8',
#     '79': 'shl edi, 8',
#     '80': 'shr ebx, 0x10',
#     '81': 'xor r12d, esi',
#     '82': 'xor r8d, edi',
#     '83': 'shr ecx, 0x10',
#     '84': 'movzx esi, cl',
#     '85': 'movzx edi, dl',
#     '86': 'movzx ebp, al',
#     '87': 'movzx esi, byte ptr [r14 + rsi]',
#     '88': 'movzx edi, byte ptr [r14 + rdi]',
#     '89': 'movzx ebp, byte ptr [r14 + rbp]',
#     '90': 'shl esi, 0x10',
#     '91': 'shl edi, 0x10',
#     '92': 'shl ebp, 0x10',
#     '93': 'xor r10d, esi',
#     '94': 'xor r11d, edi',
#     '95': 'xor r12d, ebp',
#     '96': 'movzx esi, bl',
#     '97': 'movzx edi, bh',
#     '98': 'movzx ebp, ch',
#     '99': 'movzx esi, byte ptr [r14 + rsi]',
#     '100': 'movzx edi, byte ptr [r14 + rdi]',
#     '101': 'movzx ebp, byte ptr [r14 + rbp]',
#     '102': 'shl esi, 0x10',
#     '103': 'shl edi, 0x18',
#     '104': 'shl ebp, 0x18',
#     '105': 'xor r8d, esi',
#     '106': 'xor r10d, edi',
#     '107': 'xor r11d, ebp',
#     '108': 'movzx esi, dh',
#     '109': 'movzx edi, ah',
#     '110': 'mov edx, dword ptr [r15 + 0x1c]',
#     '111': 'movzx esi, byte ptr [r14 + rsi]',
#     '112': 'movzx edi, byte ptr [r14 + rdi]',
#     '113': 'mov eax, dword ptr [r15 + 0x10]',
#     '114': 'shl esi, 0x18',
#     '115': 'shl edi, 0x18',
#     '116': 'xor r12d, esi',
#     '117': 'xor r8d, edi',
#     '118': 'mov ebx, dword ptr [r15 + 0x14]',
#     '119': 'mov ecx, dword ptr [r15 + 0x18]',
#     '120': 'lea r14, [r14 - 0x800]',
#     '121': 'xor eax, r10d',
#     '122': 'xor ebx, r11d',
#     '123': 'xor ecx, r12d',
#     '124': 'xor edx, r8d',
#     '125': 'repz ret '}},
#   {'func_name': '_x86_64_AES_decrypt_compact',
#    'func_instr': {'1': 'lea r8, [r14 + 0x80]',
#     '2': 'mov edi, dword ptr [r8 - 0x80]',
#     '3': 'mov ebp, dword ptr [r8 - 0x60]',
#     '4': 'mov r10d, dword ptr [r8 - 0x40]',
#     '5': 'mov r11d, dword ptr [r8 - 0x20]',
#     '6': 'mov edi, dword ptr [r8]',
#     '7': 'mov ebp, dword ptr [r8 + 0x20]',
#     '8': 'mov r10d, dword ptr [r8 + 0x40]',
#     '9': 'mov r11d, dword ptr [r8 + 0x60]',
#     '10': 'jmp 0x494830',
#     '11': 'xor eax, dword ptr [r15]',
#     '12': 'xor ebx, dword ptr [r15 + 4]',
#     '13': 'xor ecx, dword ptr [r15 + 8]',
#     '14': 'xor edx, dword ptr [r15 + 0xc]',
#     '15': 'lea r15, [r15 + 0x10]',
#     '16': 'movzx r10d, al',
#     '17': 'movzx r11d, bl',
#     '18': 'movzx r12d, cl',
#     '19': 'movzx r8d, dl',
#     '20': 'movzx esi, dh',
#     '21': 'movzx edi, ah',
#     '22': 'shr edx, 0x10',
#     '23': 'movzx ebp, bh',
#     '24': 'movzx r10d, byte ptr [r14 + r10]',
#     '25': 'movzx r11d, byte ptr [r14 + r11]',
#     '26': 'movzx r12d, byte ptr [r14 + r12]',
#     '27': 'movzx r8d, byte ptr [r14 + r8]',
#     '28': 'movzx r9d, byte ptr [r14 + rsi]',
#     '29': 'movzx esi, ch',
#     '30': 'movzx r13d, byte ptr [r14 + rdi]',
#     '31': 'movzx ebp, byte ptr [r14 + rbp]',
#     '32': 'movzx esi, byte ptr [r14 + rsi]',
#     '33': 'shr ecx, 0x10',
#     '34': 'shl r13d, 8',
#     '35': 'shl r9d, 8',
#     '36': 'movzx edi, cl',
#     '37': 'shr eax, 0x10',
#     '38': 'xor r10d, r9d',
#     '39': 'shr ebx, 0x10',
#     '40': 'movzx r9d, dl',
#     '41': 'shl ebp, 8',
#     '42': 'xor r11d, r13d',
#     '43': 'shl esi, 8',
#     '44': 'movzx r13d, al',
#     '45': 'movzx edi, byte ptr [r14 + rdi]',
#     '46': 'xor r12d, ebp',
#     '47': 'movzx ebp, bl',
#     '48': 'shl edi, 0x10',
#     '49': 'xor r8d, esi',
#     '50': 'movzx r9d, byte ptr [r14 + r9]',
#     '51': 'movzx esi, bh',
#     '52': 'movzx ebp, byte ptr [r14 + rbp]',
#     '53': 'xor r10d, edi',
#     '54': 'movzx r13d, byte ptr [r14 + r13]',
#     '55': 'movzx edi, ch',
#     '56': 'shl ebp, 0x10',
#     '57': 'shl r9d, 0x10',
#     '58': 'shl r13d, 0x10',
#     '59': 'xor r8d, ebp',
#     '60': 'movzx ebp, dh',
#     '61': 'xor r11d, r9d',
#     '62': 'shr eax, 8',
#     '63': 'xor r12d, r13d',
#     '64': 'movzx esi, byte ptr [r14 + rsi]',
#     '65': 'movzx ebx, byte ptr [r14 + rdi]',
#     '66': 'movzx ecx, byte ptr [r14 + rbp]',
#     '67': 'movzx edx, byte ptr [r14 + rax]',
#     '68': 'mov eax, r10d',
#     '69': 'shl esi, 0x18',
#     '70': 'shl ebx, 0x18',
#     '71': 'shl ecx, 0x18',
#     '72': 'xor eax, esi',
#     '73': 'shl edx, 0x18',
#     '74': 'xor ebx, r11d',
#     '75': 'xor ecx, r12d',
#     '76': 'xor edx, r8d',
#     '77': 'cmp r15, qword ptr [rsp + 0x10]',
#     '78': 'je 0x494ad0',
#     '79': 'mov rsi, qword ptr [r14 + 0x100]',
#     '80': 'shl rbx, 0x20',
#     '81': 'shl rdx, 0x20',
#     '82': 'mov rdi, qword ptr [r14 + 0x108]',
#     '83': 'or rax, rbx',
#     '84': 'or rcx, rdx',
#     '85': 'mov rbp, qword ptr [r14 + 0x110]',
#     '86': 'mov r9, rsi',
#     '87': 'mov r12, rsi',
#     '88': 'and r9, rax',
#     '89': 'and r12, rcx',
#     '90': 'mov rbx, r9',
#     '91': 'mov rdx, r12',
#     '92': 'shr r9, 7',
#     '93': 'lea r8, [rax + rax]',
#     '94': 'shr r12, 7',
#     '95': 'lea r11, [rcx + rcx]',
#     '96': 'sub rbx, r9',
#     '97': 'sub rdx, r12',
#     '98': 'and r8, rdi',
#     '99': 'and r11, rdi',
#     '100': 'and rbx, rbp',
#     '101': 'and rdx, rbp',
#     '102': 'xor r8, rbx',
#     '103': 'xor r11, rdx',
#     '104': 'mov r10, rsi',
#     '105': 'mov r13, rsi',
#     '106': 'and r10, r8',
#     '107': 'and r13, r11',
#     '108': 'mov rbx, r10',
#     '109': 'mov rdx, r13',
#     '110': 'shr r10, 7',
#     '111': 'lea r9, [r8 + r8]',
#     '112': 'shr r13, 7',
#     '113': 'lea r12, [r11 + r11]',
#     '114': 'sub rbx, r10',
#     '115': 'sub rdx, r13',
#     '116': 'and r9, rdi',
#     '117': 'and r12, rdi',
#     '118': 'and rbx, rbp',
#     '119': 'and rdx, rbp',
#     '120': 'xor r9, rbx',
#     '121': 'xor r12, rdx',
#     '122': 'mov r10, rsi',
#     '123': 'mov r13, rsi',
#     '124': 'and r10, r9',
#     '125': 'and r13, r12',
#     '126': 'mov rbx, r10',
#     '127': 'mov rdx, r13',
#     '128': 'shr r10, 7',
#     '129': 'xor r8, rax',
#     '130': 'shr r13, 7',
#     '131': 'xor r11, rcx',
#     '132': 'sub rbx, r10',
#     '133': 'sub rdx, r13',
#     '134': 'lea r10, [r9 + r9]',
#     '135': 'lea r13, [r12 + r12]',
#     '136': 'xor r9, rax',
#     '137': 'xor r12, rcx',
#     '138': 'and r10, rdi',
#     '139': 'and r13, rdi',
#     '140': 'and rbx, rbp',
#     '141': 'and rdx, rbp',
#     '142': 'xor r10, rbx',
#     '143': 'xor r13, rdx',
#     '144': 'xor rax, r10',
#     '145': 'xor rcx, r13',
#     '146': 'xor r8, r10',
#     '147': 'xor r11, r13',
#     '148': 'mov rbx, rax',
#     '149': 'mov rdx, rcx',
#     '150': 'xor r9, r10',
#     '151': 'shr rbx, 0x20',
#     '152': 'xor r12, r13',
#     '153': 'shr rdx, 0x20',
#     '154': 'xor r10, r8',
#     '155': 'rol eax, 8',
#     '156': 'xor r13, r11',
#     '157': 'rol ecx, 8',
#     '158': 'xor r10, r9',
#     '159': 'rol ebx, 8',
#     '160': 'xor r13, r12',
#     '161': 'rol edx, 8',
#     '162': 'xor eax, r10d',
#     '163': 'shr r10, 0x20',
#     '164': 'xor ecx, r13d',
#     '165': 'shr r13, 0x20',
#     '166': 'xor ebx, r10d',
#     '167': 'xor edx, r13d',
#     '168': 'mov r10, r8',
#     '169': 'rol r8d, 0x18',
#     '170': 'mov r13, r11',
#     '171': 'rol r11d, 0x18',
#     '172': 'shr r10, 0x20',
#     '173': 'xor eax, r8d',
#     '174': 'shr r13, 0x20',
#     '175': 'xor ecx, r11d',
#     '176': 'rol r10d, 0x18',
#     '177': 'mov r8, r9',
#     '178': 'rol r13d, 0x18',
#     '179': 'mov r11, r12',
#     '180': 'shr r8, 0x20',
#     '181': 'xor ebx, r10d',
#     '182': 'shr r11, 0x20',
#     '183': 'xor edx, r13d',
#     '184': 'mov rsi, qword ptr [r14]',
#     '185': 'rol r9d, 0x10',
#     '186': 'mov rdi, qword ptr [r14 + 0x40]',
#     '187': 'rol r12d, 0x10',
#     '188': 'mov rbp, qword ptr [r14 + 0x80]',
#     '189': 'rol r8d, 0x10',
#     '190': 'mov r10, qword ptr [r14 + 0xc0]',
#     '191': 'xor eax, r9d',
#     '192': 'rol r11d, 0x10',
#     '193': 'xor ecx, r12d',
#     '194': 'mov r13, qword ptr [r14 + 0x100]',
#     '195': 'xor ebx, r8d',
#     '196': 'xor edx, r11d',
#     '197': 'jmp 0x494830',
#     '198': 'xor eax, dword ptr [r15]',
#     '199': 'xor ebx, dword ptr [r15 + 4]',
#     '200': 'xor ecx, dword ptr [r15 + 8]',
#     '201': 'xor edx, dword ptr [r15 + 0xc]',
#     '202': 'repz ret '}},
#   {'func_name': 'AES_decrypt',
#    'func_instr': {'1': 'mov rax, rsp',
#     '2': 'push rbx',
#     '3': 'push rbp',
#     '4': 'push r12',
#     '5': 'push r13',
#     '6': 'push r14',
#     '7': 'push r15',
#     '8': 'lea rcx, [rdx - 0x3f]',
#     '9': 'and rsp, 0xffffffffffffffc0',
#     '10': 'sub rcx, rsp',
#     '11': 'neg rcx',
#     '12': 'and rcx, 0x3c0',
#     '13': 'sub rsp, rcx',
#     '14': 'sub rsp, 0x20',
#     '15': 'mov qword ptr [rsp + 0x10], rsi',
#     '16': 'mov qword ptr [rsp + 0x18], rax',
#     '17': 'mov r15, rdx',
#     '18': 'mov r13d, dword ptr [r15 + 0xf0]',
#     '19': 'mov eax, dword ptr [rdi]',
#     '20': 'mov ebx, dword ptr [rdi + 4]',
#     '21': 'mov ecx, dword ptr [rdi + 8]',
#     '22': 'mov edx, dword ptr [rdi + 0xc]',
#     '23': 'shl r13d, 4',
#     '24': 'lea rbp, [r15 + r13]',
#     '25': 'mov qword ptr [rsp], r15',
#     '26': 'mov qword ptr [rsp + 8], rbp',
#     '27': 'lea r14, [rip + 0x1f30]',
#     '28': 'lea rbp, [rsp + 0x300]',
#     '29': 'sub rbp, r14',
#     '30': 'and rbp, 0x300',
#     '31': 'lea r14, [r14 + rbp]',
#     '32': 'shr rbp, 3',
#     '33': 'add r14, rbp',
#     '34': 'call 0x494800',
#     '35': 'mov r9, qword ptr [rsp + 0x10]',
#     '36': 'mov rsi, qword ptr [rsp + 0x18]',
#     '37': 'mov dword ptr [r9], eax',
#     '38': 'mov dword ptr [r9 + 4], ebx',
#     '39': 'mov dword ptr [r9 + 8], ecx',
#     '40': 'mov dword ptr [r9 + 0xc], edx',
#     '41': 'mov r15, qword ptr [rsi - 0x30]',
#     '42': 'mov r14, qword ptr [rsi - 0x28]',
#     '43': 'mov r13, qword ptr [rsi - 0x20]',
#     '44': 'mov r12, qword ptr [rsi - 0x18]',
#     '45': 'mov rbp, qword ptr [rsi - 0x10]',
#     '46': 'mov rbx, qword ptr [rsi - 8]',
#     '47': 'lea rsp, [rsi]',
#     '48': 'repz ret '}},
#   {'func_name': 'AES_set_encrypt_key',
#    'func_instr': {'1': 'push rbx',
#     '2': 'push rbp',
#     '3': 'push r12',
#     '4': 'push r13',
#     '5': 'push r14',
#     '6': 'push r15',
#     '7': 'sub rsp, 8',
#     '8': 'call 0x494be0',
#     '9': 'mov rbp, qword ptr [rsp + 0x28]',
#     '10': 'mov rbx, qword ptr [rsp + 0x30]',
#     '11': 'add rsp, 0x38',
#     '12': 'repz ret '}},
#   {'func_name': '_x86_64_AES_set_encrypt_key',
#    'func_instr': {'1': 'mov ecx, esi',
#     '2': 'mov rsi, rdi',
#     '3': 'mov rdi, rdx',
#     '4': 'test rsi, -1',
#     '5': 'je 0x494e60',
#     '6': 'test rdi, -1',
#     '7': 'je 0x494e60',
#     '8': 'lea rbp, [rip + 0xa37]',
#     '9': 'lea rbp, [rbp + 0x880]',
#     '10': 'mov eax, dword ptr [rbp - 0x80]',
#     '11': 'mov ebx, dword ptr [rbp - 0x60]',
#     '12': 'mov r8d, dword ptr [rbp - 0x40]',
#     '13': 'mov edx, dword ptr [rbp - 0x20]',
#     '14': 'mov eax, dword ptr [rbp]',
#     '15': 'mov ebx, dword ptr [rbp + 0x20]',
#     '16': 'mov r8d, dword ptr [rbp + 0x40]',
#     '17': 'mov edx, dword ptr [rbp + 0x60]',
#     '18': 'cmp ecx, 0x80',
#     '19': 'je 0x494c56',
#     '20': 'cmp ecx, 0xc0',
#     '21': 'je 0x494cdc',
#     '22': 'cmp ecx, 0x100',
#     '23': 'je 0x494d7a',
#     '24': 'mov rax, 0xfffffffffffffffe',
#     '25': 'jmp 0x494e67',
#     '26': 'mov rax, qword ptr [rsi]',
#     '27': 'mov rdx, qword ptr [rsi + 8]',
#     '28': 'mov qword ptr [rdi], rax',
#     '29': 'mov qword ptr [rdi + 8], rdx',
#     '30': 'shr rdx, 0x20',
#     '31': 'xor ecx, ecx',
#     '32': 'jmp 0x494c71',
#     '33': 'mov eax, dword ptr [rdi]',
#     '34': 'mov edx, dword ptr [rdi + 0xc]',
#     '35': 'movzx esi, dl',
#     '36': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '37': 'movzx esi, dh',
#     '38': 'shl ebx, 0x18',
#     '39': 'xor eax, ebx',
#     '40': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '41': 'shr edx, 0x10',
#     '42': 'movzx esi, dl',
#     '43': 'xor eax, ebx',
#     '44': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '45': 'movzx esi, dh',
#     '46': 'shl ebx, 8',
#     '47': 'xor eax, ebx',
#     '48': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '49': 'shl ebx, 0x10',
#     '50': 'xor eax, ebx',
#     '51': 'xor eax, dword ptr [rbp + rcx*4 + 0x380]',
#     '52': 'mov dword ptr [rdi + 0x10], eax',
#     '53': 'xor eax, dword ptr [rdi + 4]',
#     '54': 'mov dword ptr [rdi + 0x14], eax',
#     '55': 'xor eax, dword ptr [rdi + 8]',
#     '56': 'mov dword ptr [rdi + 0x18], eax',
#     '57': 'xor eax, dword ptr [rdi + 0xc]',
#     '58': 'mov dword ptr [rdi + 0x1c], eax',
#     '59': 'add ecx, 1',
#     '60': 'lea rdi, [rdi + 0x10]',
#     '61': 'cmp ecx, 0xa',
#     '62': 'jl 0x494c6c',
#     '63': 'mov dword ptr [rdi + 0x50], 0xa',
#     '64': 'xor rax, rax',
#     '65': 'jmp 0x494e67',
#     '66': 'mov rax, qword ptr [rsi]',
#     '67': 'mov rbx, qword ptr [rsi + 8]',
#     '68': 'mov rdx, qword ptr [rsi + 0x10]',
#     '69': 'mov qword ptr [rdi], rax',
#     '70': 'mov qword ptr [rdi + 8], rbx',
#     '71': 'mov qword ptr [rdi + 0x10], rdx',
#     '72': 'shr rdx, 0x20',
#     '73': 'xor ecx, ecx',
#     '74': 'jmp 0x494d01',
#     '75': 'mov eax, dword ptr [rdi]',
#     '76': 'mov edx, dword ptr [rdi + 0x14]',
#     '77': 'movzx esi, dl',
#     '78': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '79': 'movzx esi, dh',
#     '80': 'shl ebx, 0x18',
#     '81': 'xor eax, ebx',
#     '82': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '83': 'shr edx, 0x10',
#     '84': 'movzx esi, dl',
#     '85': 'xor eax, ebx',
#     '86': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '87': 'movzx esi, dh',
#     '88': 'shl ebx, 8',
#     '89': 'xor eax, ebx',
#     '90': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '91': 'shl ebx, 0x10',
#     '92': 'xor eax, ebx',
#     '93': 'xor eax, dword ptr [rbp + rcx*4 + 0x380]',
#     '94': 'mov dword ptr [rdi + 0x18], eax',
#     '95': 'xor eax, dword ptr [rdi + 4]',
#     '96': 'mov dword ptr [rdi + 0x1c], eax',
#     '97': 'xor eax, dword ptr [rdi + 8]',
#     '98': 'mov dword ptr [rdi + 0x20], eax',
#     '99': 'xor eax, dword ptr [rdi + 0xc]',
#     '100': 'mov dword ptr [rdi + 0x24], eax',
#     '101': 'cmp ecx, 7',
#     '102': 'je 0x494d6b',
#     '103': 'add ecx, 1',
#     '104': 'xor eax, dword ptr [rdi + 0x10]',
#     '105': 'mov dword ptr [rdi + 0x28], eax',
#     '106': 'xor eax, dword ptr [rdi + 0x14]',
#     '107': 'mov dword ptr [rdi + 0x2c], eax',
#     '108': 'lea rdi, [rdi + 0x18]',
#     '109': 'jmp 0x494cfc',
#     '110': 'mov dword ptr [rdi + 0x48], 0xc',
#     '111': 'xor rax, rax',
#     '112': 'jmp 0x494e67',
#     '113': 'mov rax, qword ptr [rsi]',
#     '114': 'mov rbx, qword ptr [rsi + 8]',
#     '115': 'mov rcx, qword ptr [rsi + 0x10]',
#     '116': 'mov rdx, qword ptr [rsi + 0x18]',
#     '117': 'mov qword ptr [rdi], rax',
#     '118': 'mov qword ptr [rdi + 8], rbx',
#     '119': 'mov qword ptr [rdi + 0x10], rcx',
#     '120': 'mov qword ptr [rdi + 0x18], rdx',
#     '121': 'shr rdx, 0x20',
#     '122': 'xor ecx, ecx',
#     '123': 'jmp 0x494da5',
#     '124': 'mov eax, dword ptr [rdi]',
#     '125': 'mov edx, dword ptr [rdi + 0x1c]',
#     '126': 'movzx esi, dl',
#     '127': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '128': 'movzx esi, dh',
#     '129': 'shl ebx, 0x18',
#     '130': 'xor eax, ebx',
#     '131': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '132': 'shr edx, 0x10',
#     '133': 'movzx esi, dl',
#     '134': 'xor eax, ebx',
#     '135': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '136': 'movzx esi, dh',
#     '137': 'shl ebx, 8',
#     '138': 'xor eax, ebx',
#     '139': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '140': 'shl ebx, 0x10',
#     '141': 'xor eax, ebx',
#     '142': 'xor eax, dword ptr [rbp + rcx*4 + 0x380]',
#     '143': 'mov dword ptr [rdi + 0x20], eax',
#     '144': 'xor eax, dword ptr [rdi + 4]',
#     '145': 'mov dword ptr [rdi + 0x24], eax',
#     '146': 'xor eax, dword ptr [rdi + 8]',
#     '147': 'mov dword ptr [rdi + 0x28], eax',
#     '148': 'xor eax, dword ptr [rdi + 0xc]',
#     '149': 'mov dword ptr [rdi + 0x2c], eax',
#     '150': 'cmp ecx, 6',
#     '151': 'je 0x494e54',
#     '152': 'add ecx, 1',
#     '153': 'mov edx, eax',
#     '154': 'mov eax, dword ptr [rdi + 0x10]',
#     '155': 'movzx esi, dl',
#     '156': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '157': 'movzx esi, dh',
#     '158': 'xor eax, ebx',
#     '159': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '160': 'shr edx, 0x10',
#     '161': 'shl ebx, 8',
#     '162': 'movzx esi, dl',
#     '163': 'xor eax, ebx',
#     '164': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '165': 'movzx esi, dh',
#     '166': 'shl ebx, 0x10',
#     '167': 'xor eax, ebx',
#     '168': 'movzx ebx, byte ptr [rbp + rsi - 0x80]',
#     '169': 'shl ebx, 0x18',
#     '170': 'xor eax, ebx',
#     '171': 'mov dword ptr [rdi + 0x30], eax',
#     '172': 'xor eax, dword ptr [rdi + 0x14]',
#     '173': 'mov dword ptr [rdi + 0x34], eax',
#     '174': 'xor eax, dword ptr [rdi + 0x18]',
#     '175': 'mov dword ptr [rdi + 0x38], eax',
#     '176': 'xor eax, dword ptr [rdi + 0x1c]',
#     '177': 'mov dword ptr [rdi + 0x3c], eax',
#     '178': 'lea rdi, [rdi + 0x20]',
#     '179': 'jmp 0x494da0',
#     '180': 'mov dword ptr [rdi + 0x30], 0xe',
#     '181': 'xor rax, rax',
#     '182': 'jmp 0x494e67',
#     '183': 'mov rax, 0xffffffffffffffff',
#     '184': 'repz ret '}},
#   {'func_name': 'AES_set_decrypt_key',
#    'func_instr': {'1': 'push rbx',
#     '2': 'push rbp',
#     '3': 'push r12',
#     '4': 'push r13',
#     '5': 'push r14',
#     '6': 'push r15',
#     '7': 'push rdx',
#     '8': 'call 0x494be0',
#     '9': 'mov r8, qword ptr [rsp]',
#     '10': 'cmp eax, 0',
#     '11': 'jne 0x495069',
#     '12': 'mov r14d, dword ptr [r8 + 0xf0]',
#     '13': 'xor rdi, rdi',
#     '14': 'lea rcx, [rdi + r14*4]',
#     '15': 'mov rsi, r8',
#     '16': 'lea rdi, [r8 + rcx*4]',
#     '17': 'nop ',
#     '18': 'mov rax, qword ptr [rsi]',
#     '19': 'mov rbx, qword ptr [rsi + 8]',
#     '20': 'mov rcx, qword ptr [rdi]',
#     '21': 'mov rdx, qword ptr [rdi + 8]',
#     '22': 'mov qword ptr [rdi], rax',
#     '23': 'mov qword ptr [rdi + 8], rbx',
#     '24': 'mov qword ptr [rsi], rcx',
#     '25': 'mov qword ptr [rsi + 8], rdx',
#     '26': 'lea rsi, [rsi + 0x10]',
#     '27': 'lea rdi, [rdi - 0x10]',
#     '28': 'cmp rdi, rsi',
#     '29': 'jne 0x494ea4',
#     '30': 'lea rax, [rip + 0x136c]',
#     '31': 'mov rsi, qword ptr [rax + 0x28]',
#     '32': 'mov rdi, qword ptr [rax + 0x30]',
#     '33': 'mov rbp, qword ptr [rax + 0x38]',
#     '34': 'mov r15, r8',
#     '35': 'sub r14d, 1',
#     '36': 'nop ',
#     '37': 'lea r15, [r15 + 0x10]',
#     '38': 'mov rax, qword ptr [r15]',
#     '39': 'mov rcx, qword ptr [r15 + 8]',
#     '40': 'mov r9, rsi',
#     '41': 'mov r12, rsi',
#     '42': 'and r9, rax',
#     '43': 'and r12, rcx',
#     '44': 'mov rbx, r9',
#     '45': 'mov rdx, r12',
#     '46': 'shr r9, 7',
#     '47': 'lea r8, [rax + rax]',
#     '48': 'shr r12, 7',
#     '49': 'lea r11, [rcx + rcx]',
#     '50': 'sub rbx, r9',
#     '51': 'sub rdx, r12',
#     '52': 'and r8, rdi',
#     '53': 'and r11, rdi',
#     '54': 'and rbx, rbp',
#     '55': 'and rdx, rbp',
#     '56': 'xor r8, rbx',
#     '57': 'xor r11, rdx',
#     '58': 'mov r10, rsi',
#     '59': 'mov r13, rsi',
#     '60': 'and r10, r8',
#     '61': 'and r13, r11',
#     '62': 'mov rbx, r10',
#     '63': 'mov rdx, r13',
#     '64': 'shr r10, 7',
#     '65': 'lea r9, [r8 + r8]',
#     '66': 'shr r13, 7',
#     '67': 'lea r12, [r11 + r11]',
#     '68': 'sub rbx, r10',
#     '69': 'sub rdx, r13',
#     '70': 'and r9, rdi',
#     '71': 'and r12, rdi',
#     '72': 'and rbx, rbp',
#     '73': 'and rdx, rbp',
#     '74': 'xor r9, rbx',
#     '75': 'xor r12, rdx',
#     '76': 'mov r10, rsi',
#     '77': 'mov r13, rsi',
#     '78': 'and r10, r9',
#     '79': 'and r13, r12',
#     '80': 'mov rbx, r10',
#     '81': 'mov rdx, r13',
#     '82': 'shr r10, 7',
#     '83': 'xor r8, rax',
#     '84': 'shr r13, 7',
#     '85': 'xor r11, rcx',
#     '86': 'sub rbx, r10',
#     '87': 'sub rdx, r13',
#     '88': 'lea r10, [r9 + r9]',
#     '89': 'lea r13, [r12 + r12]',
#     '90': 'xor r9, rax',
#     '91': 'xor r12, rcx',
#     '92': 'and r10, rdi',
#     '93': 'and r13, rdi',
#     '94': 'and rbx, rbp',
#     '95': 'and rdx, rbp',
#     '96': 'xor r10, rbx',
#     '97': 'xor r13, rdx',
#     '98': 'xor rax, r10',
#     '99': 'xor rcx, r13',
#     '100': 'xor r8, r10',
#     '101': 'xor r11, r13',
#     '102': 'mov rbx, rax',
#     '103': 'mov rdx, rcx',
#     '104': 'xor r9, r10',
#     '105': 'shr rbx, 0x20',
#     '106': 'xor r12, r13',
#     '107': 'shr rdx, 0x20',
#     '108': 'xor r10, r8',
#     '109': 'rol eax, 8',
#     '110': 'xor r13, r11',
#     '111': 'rol ecx, 8',
#     '112': 'xor r10, r9',
#     '113': 'rol ebx, 8',
#     '114': 'xor r13, r12',
#     '115': 'rol edx, 8',
#     '116': 'xor eax, r10d',
#     '117': 'shr r10, 0x20',
#     '118': 'xor ecx, r13d',
#     '119': 'shr r13, 0x20',
#     '120': 'xor ebx, r10d',
#     '121': 'xor edx, r13d',
#     '122': 'mov r10, r8',
#     '123': 'rol r8d, 0x18',
#     '124': 'mov r13, r11',
#     '125': 'rol r11d, 0x18',
#     '126': 'shr r10, 0x20',
#     '127': 'xor eax, r8d',
#     '128': 'shr r13, 0x20',
#     '129': 'xor ecx, r11d',
#     '130': 'rol r10d, 0x18',
#     '131': 'mov r8, r9',
#     '132': 'rol r13d, 0x18',
#     '133': 'mov r11, r12',
#     '134': 'shr r8, 0x20',
#     '135': 'xor ebx, r10d',
#     '136': 'shr r11, 0x20',
#     '137': 'xor edx, r13d',
#     '138': 'rol r9d, 0x10',
#     '139': 'rol r12d, 0x10',
#     '140': 'rol r8d, 0x10',
#     '141': 'xor eax, r9d',
#     '142': 'rol r11d, 0x10',
#     '143': 'xor ecx, r12d',
#     '144': 'xor ebx, r8d',
#     '145': 'xor edx, r11d',
#     '146': 'mov dword ptr [r15], eax',
#     '147': 'mov dword ptr [r15 + 4], ebx',
#     '148': 'mov dword ptr [r15 + 8], ecx',
#     '149': 'mov dword ptr [r15 + 0xc], edx',
#     '150': 'sub r14d, 1',
#     '151': 'jne 0x494ee8',
#     '152': 'xor rax, rax',
#     '153': 'mov r15, qword ptr [rsp + 8]',
#     '154': 'mov r14, qword ptr [rsp + 0x10]',
#     '155': 'mov r13, qword ptr [rsp + 0x18]',
#     '156': 'mov r12, qword ptr [rsp + 0x20]',
#     '157': 'mov rbp, qword ptr [rsp + 0x28]',
#     '158': 'mov rbx, qword ptr [rsp + 0x30]',
#     '159': 'add rsp, 0x38',
#     '160': 'repz ret '}},
#   {'func_name': 'AES_cbc_encrypt',
#    'func_instr': {'1': 'cmp rdx, 0',
#     '2': 'je 0x495611',
#     '3': 'pushfq ',
#     '4': 'push rbx',
#     '5': 'push rbp',
#     '6': 'push r12',
#     '7': 'push r13',
#     '8': 'push r14',
#     '9': 'push r15',
#     '10': 'cld ',
#     '11': 'mov r9d, r9d',
#     '12': 'lea r14, [rip + 0x590]',
#     '13': 'lea r10, [rip + 0x11c9]',
#     '14': 'cmp r9, 0',
#     '15': 'cmove r14, r10',
#     '16': 'mov r10d, dword ptr [rip + 0x597dda]',
#     '17': 'cmp rdx, 0x200',
#     '18': 'jb 0x4953b0',
#     '19': 'test rdx, 0xf',
#     '20': 'jne 0x4953b0',
#     '21': 'bt r10d, 0x1c',
#     '22': 'jb 0x4953b0',
#     '23': 'lea r15, [rsp - 0x150]',
#     '24': 'and r15, 0xffffffffffffffc0',
#     '25': 'mov r10, r14',
#     '26': 'lea r11, [r14 + 0x900]',
#     '27': 'mov r12, r15',
#     '28': 'and r10, 0xfff',
#     '29': 'and r11, 0xfff',
#     '30': 'and r12, 0xfff',
#     '31': 'cmp r12, r11',
#     '32': 'jb 0x495126',
#     '33': 'sub r12, r11',
#     '34': 'sub r15, r12',
#     '35': 'jmp 0x49513c',
#     '36': 'sub r12, r10',
#     '37': 'and r12, 0xfff',
#     '38': 'add r12, 0x140',
#     '39': 'sub r15, r12',
#     '40': 'nop ',
#     '41': 'xchg r15, rsp',
#     '42': 'mov qword ptr [rsp + 0x10], r15',
#     '43': 'mov qword ptr [rsp + 0x18], rdi',
#     '44': 'mov qword ptr [rsp + 0x20], rsi',
#     '45': 'mov qword ptr [rsp + 0x28], rdx',
#     '46': 'mov qword ptr [rsp + 0x30], rcx',
#     '47': 'mov qword ptr [rsp + 0x38], r8',
#     '48': 'mov dword ptr [rsp + 0x140], 0',
#     '49': 'mov rbp, r8',
#     '50': 'mov rbx, r9',
#     '51': 'mov r9, rsi',
#     '52': 'mov r8, rdi',
#     '53': 'mov r15, rcx',
#     '54': 'mov eax, dword ptr [r15 + 0xf0]',
#     '55': 'mov r10, r15',
#     '56': 'sub r10, r14',
#     '57': 'and r10, 0xfff',
#     '58': 'cmp r10, 0x900',
#     '59': 'jb 0x4951a0',
#     '60': 'cmp r10, 0xf08',
#     '61': 'jb 0x4951b8',
#     '62': 'nop dword ptr [rax]',
#     '63': 'mov rsi, r15',
#     '64': 'lea rdi, [rsp + 0x50]',
#     '65': 'lea r15, [rsp + 0x50]',
#     '66': 'mov ecx, 0x1e',
#     '67': 'rep movsq qword ptr [rdi], qword ptr [rsi]',
#     '68': 'nop ',
#     '69': 'mov dword ptr [rdi], eax',
#     '70': 'mov qword ptr [rsp], r15',
#     '71': 'mov ecx, 0x12',
#     '72': 'nop dword ptr [rax]',
#     '73': 'mov r10, qword ptr [r14]',
#     '74': 'mov r11, qword ptr [r14 + 0x20]',
#     '75': 'mov r12, qword ptr [r14 + 0x40]',
#     '76': 'mov r13, qword ptr [r14 + 0x60]',
#     '77': 'lea r14, [r14 + 0x80]',
#     '78': 'sub ecx, 1',
#     '79': 'jne 0x4951c4',
#     '80': 'lea r14, [r14 - 0x900]',
# ...
#     '244': 'cmp dword ptr [rbp - 0x1c], 0',
#     '245': 'setg al',
#     '246': 'mov byte ptr [rbp - 0x4d], al',
#     '247': 'mov al, byte ptr [rbp - 0x4d]',
#     '248': 'test al, 1',
#     '249': 'jne 0x4ddd17',
#     '250': 'cmp dword ptr [rbp - 0x1c], 0',
#     '251': 'jle 0x4de199',
#     '252': 'mov rax, qword ptr [rbp - 0x30]',
#     '253': 'movsxd rax, dword ptr [rax + 0xc]',
#     '254': 'mov rcx, qword ptr [rbp - 0x30]',
#     '255': 'mov rcx, qword ptr [rcx]',
#     '256': 'add rcx, rax',
#     '257': 'mov rsi, qword ptr [rbp - 0x18]',
#     '258': 'movsxd rdx, dword ptr [rbp - 0x1c]',
#     '259': 'mov rdi, rcx',
#     '260': 'call 0x493630',
#     '261': 'mov eax, dword ptr [rbp - 0x24]',
#     '262': 'mov dword ptr [rbp - 4], eax',
#     '263': 'mov eax, dword ptr [rbp - 4]',
#     '264': 'add rsp, 0x50',
#     '265': 'pop rbp',
#     '266': 'ret '}},
#   {'func_name': 'linebuffer_read',
#    'func_instr': {'1': 'push rbp',
#     '2': 'mov rbp, rsp',
#     '3': 'sub rsp, 0x20',
#     '4': 'mov qword ptr [rbp - 0x10], rdi',
#     '5': 'mov qword ptr [rbp - 0x18], rsi',
#     '6': 'mov dword ptr [rbp - 0x1c], edx',
#     '7': 'mov dword ptr [rbp - 0x20], 0',
#     '8': 'cmp qword ptr [rbp - 0x18], 0',
#     '9': 'jne 0x4de1e4',
#     '10': 'mov dword ptr [rbp - 4], 0',
#     '11': 'jmp 0x4de236',
#     '12': 'mov rax, qword ptr [rbp - 0x10]',
#     '13': 'cmp qword ptr [rax + 0x40], 0',
#     '14': 'jne 0x4de202',
#     '15': 'mov dword ptr [rbp - 4], 0',
#     '16': 'jmp 0x4de236',
#     '17': 'mov rax, qword ptr [rbp - 0x10]',
#     '18': 'mov rdi, qword ptr [rax + 0x40]',
#     '19': 'mov rsi, qword ptr [rbp - 0x18]',
#     '20': 'mov edx, dword ptr [rbp - 0x1c]',
#     '21': 'call 0x4e0190',
#     '22': 'mov esi, 0xf',
#     '23': 'mov dword ptr [rbp - 0x20], eax',
#     '24': 'mov rdi, qword ptr [rbp - 0x10]',
#     '25': 'call 0x4e0020',
#     '26': 'mov rdi, qword ptr [rbp - 0x10]',
#     '27': 'call 0x4e1830',
#     '28': 'mov eax, dword ptr [rbp - 0x20]',
#     '29': 'mov dword ptr [rbp - 4], eax',
#     '30': 'mov eax, dword ptr [rbp - 4]',
#     '31': 'add rsp, 0x20',
#     '32': 'pop rbp',
#     '33': 'ret '}},
#   {'func_name': 'linebuffer_puts',
#    'func_instr': {'1': 'push rbp',
#     '2': 'mov rbp, rsp',
#     '3': 'sub rsp, 0x20',
#     '4': 'mov qword ptr [rbp - 8], rdi',
#     '5': 'mov qword ptr [rbp - 0x10], rsi',
#     '6': 'mov rdi, qword ptr [rbp - 8]',
#     '7': 'mov rsi, qword ptr [rbp - 0x10]',
#     '8': 'mov rax, qword ptr [rbp - 0x10]',
#     '9': 'mov qword ptr [rbp - 0x18], rdi',
#     '10': 'mov rdi, rax',
#     '11': 'mov qword ptr [rbp - 0x20], rsi',
#     '12': 'call 0x493140'}},
#   {'func_name': 'linebuffer_gets',
#    'func_instr': {'1': 'push rbp',
#     '2': 'mov rbp, rsp',
#     '3': 'sub rsp, 0x20',
#     '4': 'mov qword ptr [rbp - 0x10], rdi',
#     '5': 'mov qword ptr [rbp - 0x18], rsi',
#     '6': 'mov dword ptr [rbp - 0x1c], edx',
#     '7': 'mov rsi, qword ptr [rbp - 0x10]',
#     '8': 'cmp qword ptr [rsi + 0x40], 0',
#     '9': 'jne 0x4de2c1',
#     '10': 'mov dword ptr [rbp - 4], 0',
#     '11': 'jmp 0x4de2d8',
#     '12': 'mov rax, qword ptr [rbp - 0x10]',
#     '13': 'mov rdi, qword ptr [rax + 0x40]',
#     '14': 'mov rsi, qword ptr [rbp - 0x18]',
#     '15': 'mov edx, dword ptr [rbp - 0x1c]',
#     '16': 'call 0x4e0a90',
#     '17': 'mov dword ptr [rbp - 4], eax',
#     '18': 'mov eax, dword ptr [rbp - 4]',
#     '19': 'add rsp, 0x20',
#     '20': 'pop rbp',
#     '21': 'ret '}},
#   {'func_name': 'linebuffer_ctrl',
#    'func_instr': {'1': 'push rbp',
#     '2': 'mov rbp, rsp',
#     '3': 'sub rsp, 0x90',
#     '4': 'mov qword ptr [rbp - 0x10], rdi',
#     '5': 'mov dword ptr [rbp - 0x14], esi',
#     '6': 'mov qword ptr [rbp - 0x20], rdx',
#     '7': 'mov qword ptr [rbp - 0x28], rcx',
#     '8': 'mov qword ptr [rbp - 0x40], 1',
#     '9': 'mov rcx, qword ptr [rbp - 0x10]',
#     '10': 'mov rcx, qword ptr [rcx + 0x38]',
#     '11': 'mov qword ptr [rbp - 0x38], rcx',
#     '12': 'mov esi, dword ptr [rbp - 0x14]',
#     '13': 'mov eax, esi',
#     '14': 'sub eax, 0x74',
#     '15': 'mov dword ptr [rbp - 0x54], esi',
#     '16': 'mov dword ptr [rbp - 0x58], eax',
#     '17': 'jg 0x4de3d7',
#     '18': 'jmp 0x4de337',
#     '19': 'mov eax, dword ptr [rbp - 0x54]',
#     '20': 'sub eax, 0x64',
#     '21': 'mov dword ptr [rbp - 0x5c], eax',
#     '22': 'jg 0x4de3c3',
#     '23': 'jmp 0x4de34b',
#     '24': 'mov eax, dword ptr [rbp - 0x54]',
#     '25': 'sub eax, 0xa',
#     '26': 'mov dword ptr [rbp - 0x60], eax',
#     '27': 'jg 0x4de387',
#     '28': 'jmp 0x4de35f',
#     '29': 'mov eax, dword ptr [rbp - 0x54]',
#     '30': 'sub eax, 1',
#     '31': 'mov dword ptr [rbp - 0x64], eax',
#     '32': 'je 0x4de3eb',
#     '33': 'jmp 0x4de373',
#     '34': 'mov eax, dword ptr [rbp - 0x54]',
#     '35': 'sub eax, 3',
#     '36': 'mov dword ptr [rbp - 0x68], eax',
#     '37': 'je 0x4de436',
#     '38': 'jmp 0x4de76a',
#     '39': 'mov eax, dword ptr [rbp - 0x54]',
#     '40': 'sub eax, 0xb',
#     '41': 'mov dword ptr [rbp - 0x6c], eax',
#     '42': 'je 0x4de5f4',
#     '43': 'jmp 0x4de39b',
#     '44': 'mov eax, dword ptr [rbp - 0x54]',
#     '45': 'sub eax, 0xc',
#     '46': 'mov dword ptr [rbp - 0x70], eax',
#     '47': 'je 0x4de72e',
#     '48': 'jmp 0x4de3af',
#     '49': 'mov eax, dword ptr [rbp - 0x54]',
#     '50': 'sub eax, 0xd',
#     '51': 'mov dword ptr [rbp - 0x74], eax',
#     '52': 'je 0x4de447',
#     '53': 'jmp 0x4de76a',
#     '54': 'mov eax, dword ptr [rbp - 0x54]',
#     '55': 'sub eax, 0x65',
#     '56': 'mov dword ptr [rbp - 0x78], eax',
#     '57': 'je 0x4de59d',
#     '58': 'jmp 0x4de76a',
#     '59': 'mov eax, dword ptr [rbp - 0x54]',
#     '60': 'sub eax, 0x75',
#     '61': 'mov dword ptr [rbp - 0x7c], eax',
#     '62': 'je 0x4de4a1',
#     '63': 'jmp 0x4de76a',
#     '64': 'mov rax, qword ptr [rbp - 0x38]',
#     '65': 'mov dword ptr [rax + 0xc], 0',
#     '66': 'mov rax, qword ptr [rbp - 0x10]',
#     '67': 'cmp qword ptr [rax + 0x40], 0',
#     '68': 'jne 0x4de415',
#     '69': 'mov qword ptr [rbp - 8], 0',
#     '70': 'jmp 0x4de7f2',
#     '71': 'mov rax, qword ptr [rbp - 0x10]',
#     '72': 'mov rdi, qword ptr [rax + 0x40]',
#     '73': 'mov esi, dword ptr [rbp - 0x14]',
#     '74': 'mov rdx, qword ptr [rbp - 0x20]',
#     '75': 'mov rcx, qword ptr [rbp - 0x28]',
#     '76': 'call 0x4e0e20',
#     '77': 'mov qword ptr [rbp - 0x40], rax',
#     '78': 'jmp 0x4de7a5',
#     '79': 'mov rax, qword ptr [rbp - 0x38]',
#     '80': 'movsxd rax, dword ptr [rax + 0xc]',
#     '81': 'mov qword ptr [rbp - 0x40], rax',
#     '82': 'jmp 0x4de7a5',
#     '83': 'mov rax, qword ptr [rbp - 0x38]',
#     '84': 'movsxd rax, dword ptr [rax + 0xc]',
#     '85': 'mov qword ptr [rbp - 0x40], rax',
#     '86': 'cmp qword ptr [rbp - 0x40], 0',
#     '87': 'jne 0x4de49c',
#     '88': 'mov rax, qword ptr [rbp - 0x10]',
#     '89': 'cmp qword ptr [rax + 0x40], 0',
#     '90': 'jne 0x4de480',
#     '91': 'mov qword ptr [rbp - 8], 0',
#     '92': 'jmp 0x4de7f2',
#     '93': 'mov rax, qword ptr [rbp - 0x10]',
#     '94': 'mov rdi, qword ptr [rax + 0x40]',
#     '95': 'mov esi, dword ptr [rbp - 0x14]',
#     '96': 'mov rdx, qword ptr [rbp - 0x20]',
#     '97': 'mov rcx, qword ptr [rbp - 0x28]',
#     '98': 'call 0x4e0e20',
#     '99': 'mov qword ptr [rbp - 0x40], rax',
#     '100': 'jmp 0x4de7a5',
#     '101': 'mov rax, qword ptr [rbp - 0x20]',
#     '102': 'mov ecx, eax',
#     '103': 'mov dword ptr [rbp - 0x50], ecx',
#     '104': 'mov rax, qword ptr [rbp - 0x38]',
#     '105': 'mov rax, qword ptr [rax]',
#     '106': 'mov qword ptr [rbp - 0x48], rax',
#     '107': 'cmp dword ptr [rbp - 0x50], 0x2800',
#     '108': 'jle 0x4de508',
#     '109': 'mov eax, dword ptr [rbp - 0x50]',
#     '110': 'mov rcx, qword ptr [rbp - 0x38]',
#     '111': 'cmp eax, dword ptr [rcx + 8]',
#     '112': 'je 0x4de508',
#     '113': 'lea rsi, [rip + 0x275f64]',
#     '114': 'mov edx, 0xee',
#     '115': 'mov rax, qword ptr [rbp - 0x20]',
#     '116': 'mov ecx, eax',
#     '117': 'movsxd rdi, ecx',
#     '118': 'call 0x61f410',
#     '119': 'mov qword ptr [rbp - 0x48], rax',
#     '120': 'cmp qword ptr [rbp - 0x48], 0',
#     '121': 'jne 0x4de503',
#     '122': 'jmp 0x4de7b2',
#     '123': 'jmp 0x4de508',
#     '124': 'mov rax, qword ptr [rbp - 0x38]',
#     '125': 'mov rax, qword ptr [rax]',
#     '126': 'cmp rax, qword ptr [rbp - 0x48]',
#     '127': 'je 0x4de598',
#     '128': 'mov rax, qword ptr [rbp - 0x38]',
#     '129': 'mov ecx, dword ptr [rax + 0xc]',
#     '130': 'cmp ecx, dword ptr [rbp - 0x50]',
#     '131': 'jle 0x4de533',
#     '132': 'mov eax, dword ptr [rbp - 0x50]',
#     '133': 'mov rcx, qword ptr [rbp - 0x38]',
#     '134': 'mov dword ptr [rcx + 0xc], eax',
#     '135': 'lea rsi, [rip + 0x275f03]',
#     '136': 'mov edx, 0xf7',
#     '137': 'mov rdi, qword ptr [rbp - 0x48]',
#     '138': 'mov rax, qword ptr [rbp - 0x38]',
#     '139': 'mov rax, qword ptr [rax]',
#     '140': 'mov rcx, qword ptr [rbp - 0x38]',
#     '141': 'movsxd rcx, dword ptr [rcx + 0xc]',
#     '142': 'mov qword ptr [rbp - 0x88], rsi',
#     '143': 'mov rsi, rax',
#     '144': 'mov dword ptr [rbp - 0x8c], edx',
#     '145': 'mov rdx, rcx',
#     '146': 'call 0x493630',
#     '147': 'jmp 0x4de7a5',
#     '148': 'mov rax, qword ptr [rbp - 0x10]',
#     '149': 'cmp qword ptr [rax + 0x40], 0',
#     '150': 'jne 0x4de5bc',
#     '151': 'mov qword ptr [rbp - 8], 0',
#     '152': 'jmp 0x4de7f2',
#     '153': 'mov esi, 0xf',
#     '154': 'mov rdi, qword ptr [rbp - 0x10]',
#     '155': 'call 0x4e0020',
#     '156': 'mov rdi, qword ptr [rbp - 0x10]',
#     '157': 'mov rdi, qword ptr [rdi + 0x40]',
#     '158': 'mov esi, dword ptr [rbp - 0x14]',
#     '159': 'mov rdx, qword ptr [rbp - 0x20]',
#     '160': 'mov rcx, qword ptr [rbp - 0x28]',
#     '161': 'call 0x4e0e20',
#     '162': 'mov qword ptr [rbp - 0x40], rax',
#     '163': 'mov rdi, qword ptr [rbp - 0x10]',
#     '164': 'call 0x4e1830',
#     '165': 'jmp 0x4de7a5',
#     '166': 'mov rax, qword ptr [rbp - 0x10]',
#     '167': 'cmp qword ptr [rax + 0x40], 0',
#     '168': 'jne 0x4de613',
#     '169': 'mov qword ptr [rbp - 8], 0',
#     '170': 'jmp 0x4de7f2',
#     '171': 'mov rax, qword ptr [rbp - 0x38]',
#     '172': 'cmp dword ptr [rax + 0xc], 0',
#     '173': 'jg 0x4de645',
#     '174': 'mov rax, qword ptr [rbp - 0x10]',
#     '175': 'mov rdi, qword ptr [rax + 0x40]',
#     '176': 'mov esi, dword ptr [rbp - 0x14]',
#     '177': 'mov rdx, qword ptr [rbp - 0x20]',
#     '178': 'mov rcx, qword ptr [rbp - 0x28]',
#     '179': 'call 0x4e0e20',
#     '180': 'mov qword ptr [rbp - 0x40], rax',
#     '181': 'jmp 0x4de7a5',
#     '182': 'jmp 0x4de64a',
#     '183': 'mov esi, 0xf',
#     '184': 'mov rdi, qword ptr [rbp - 0x10]',
#     '185': 'call 0x4e0020',
#     '186': 'mov rdi, qword ptr [rbp - 0x38]',
#     '187': 'cmp dword ptr [rdi + 0xc], 0',
#     '188': 'jle 0x4de6f8',
#     '189': 'mov rax, qword ptr [rbp - 0x10]',
#     '190': 'mov rdi, qword ptr [rax + 0x40]',
#     '191': 'mov rax, qword ptr [rbp - 0x38]',
#     '192': 'mov rsi, qword ptr [rax]',
#     '193': 'mov rax, qword ptr [rbp - 0x38]',
#     '194': 'mov edx, dword ptr [rax + 0xc]',
#     '195': 'call 0x4e04e0',
#     '196': 'mov dword ptr [rbp - 0x4c], eax',
#     '197': 'mov rdi, qword ptr [rbp - 0x10]',
#     '198': 'call 0x4e1830',
#     '199': 'cmp dword ptr [rbp - 0x4c], 0',
#     '200': 'jg 0x4de6aa',
#     '201': 'movsxd rax, dword ptr [rbp - 0x4c]',
#     '202': 'mov qword ptr [rbp - 8], rax',
#     '203': 'jmp 0x4de7f2',
#     '204': 'mov eax, dword ptr [rbp - 0x4c]',
#     '205': 'mov rcx, qword ptr [rbp - 0x38]',
#     '206': 'cmp eax, dword ptr [rcx + 0xc]',
#     '207': 'jge 0x4de6e4',
#     '208': 'mov rax, qword ptr [rbp - 0x38]',
#     '209': 'mov rdi, qword ptr [rax]',
#     '210': 'mov rax, qword ptr [rbp - 0x38]',
#     '211': 'mov rax, qword ptr [rax]',
#     '212': 'movsxd rcx, dword ptr [rbp - 0x4c]',
#     '213': 'add rax, rcx',
#     '214': 'mov rcx, qword ptr [rbp - 0x38]',
#     '215': 'mov edx, dword ptr [rcx + 0xc]',
#     '216': 'sub edx, dword ptr [rbp - 0x4c]',
#     '217': 'movsxd rdx, edx',
#     '218': 'mov rsi, rax',
#     '219': 'call 0x493350',
#     '220': 'mov eax, dword ptr [rbp - 0x4c]',
#     '221': 'mov rcx, qword ptr [rbp - 0x38]',
#     '222': 'mov edx, dword ptr [rcx + 0xc]',
#     '223': 'sub edx, eax',
#     '224': 'mov dword ptr [rcx + 0xc], edx',
#     '225': 'jmp 0x4de708',
#     '226': 'mov rax, qword ptr [rbp - 0x38]',
#     '227': 'mov dword ptr [rax + 0xc], 0',
#     '228': 'jmp 0x4de70d',
#     '229': 'jmp 0x4de64a',
#     '230': 'mov rax, qword ptr [rbp - 0x10]',
#     '231': 'mov rdi, qword ptr [rax + 0x40]',
#     '232': 'mov esi, dword ptr [rbp - 0x14]',
#     '233': 'mov rdx, qword ptr [rbp - 0x20]',
#     '234': 'mov rcx, qword ptr [rbp - 0x28]',
#     '235': 'call 0x4e0e20',
#     '236': 'mov qword ptr [rbp - 0x40], rax',
#     '237': 'jmp 0x4de7a5',
#     '238': 'mov esi, 0x75',
#     '239': 'mov ecx, 1',
#     '240': 'mov rax, qword ptr [rbp - 0x28]',
#     '241': 'mov qword ptr [rbp - 0x30], rax',
#     '242': 'mov rdi, qword ptr [rbp - 0x30]',
#     '243': 'mov rax, qword ptr [rbp - 0x38]',
#     '244': 'movsxd rdx, dword ptr [rax + 8]',
#     '245': 'call 0x4e0de0',
#     '246': 'cmp rax, 0',
#     '247': 'jne 0x4de765',
#     '248': 'mov qword ptr [rbp - 0x40], 0',
#     '249': 'jmp 0x4de7a5',
#     '250': 'mov rax, qword ptr [rbp - 0x10]',
#     '251': 'cmp qword ptr [rax + 0x40], 0',
#     '252': 'jne 0x4de789',
#     '253': 'mov qword ptr [rbp - 8], 0',
#     '254': 'jmp 0x4de7f2',
#     '255': 'mov rax, qword ptr [rbp - 0x10]',
#     '256': 'mov rdi, qword ptr [rax + 0x40]',
#     '257': 'mov esi, dword ptr [rbp - 0x14]',
#     '258': 'mov rdx, qword ptr [rbp - 0x20]',
#     '259': 'mov rcx, qword ptr [rbp - 0x28]',
#     '260': 'call 0x4e0e20',
#     '261': 'mov qword ptr [rbp - 0x40], rax',
#     '262': 'mov rax, qword ptr [rbp - 0x40]',
#     '263': 'mov qword ptr [rbp - 8], rax',
#     '264': 'jmp 0x4de7f2',
#     '265': 'call 0x5d2650',
#     '266': 'lea rdi, [rip + 0x275c7f]',
#     '267': 'mov esi, 0x12a',
#     '268': 'lea rdx, [rip + 0x275c97]',
#     '269': 'call 0x5d2790',
#     '270': 'mov edi, 0x20',
#     '271': 'mov esi, 0x41',
#     '272': 'movabs rdx, 0',
#     '273': 'mov al, 0',
#     '274': 'call 0x5d2850',
#     '275': 'mov qword ptr [rbp - 8], 0',
#     '276': 'mov rax, qword ptr [rbp - 8]',
#     '277': 'add rsp, 0x90',
#     '278': 'pop rbp',
#     '279': 'ret '}},
#   {'func_name': 'linebuffer_new',
#    'func_instr': {'1': 'push rbp',
#     '2': 'mov rbp, rsp',
#     '3': 'sub rsp, 0x20',
#     '4': 'movabs rax, 0x10',
#     '5': 'lea rsi, [rip + 0x275c24]',
#     '6': 'mov edx, 0x3e',
#     '7': 'mov qword ptr [rbp - 0x10], rdi',
#     '8': 'mov rdi, rax',
#     '9': 'call 0x61f410',
#     '10': 'mov qword ptr [rbp - 0x18], rax',
#     '11': 'cmp rax, 0',
#     '12': 'jne 0x4de87e',
#     '13': 'call 0x5d2650',
#     '14': 'lea rdi, [rip + 0x275bf7]',
#     '15': 'mov esi, 0x3f',
#     '16': 'lea rdx, [rip + 0x275c00]',
#     '17': 'call 0x5d2790',
#     '18': 'mov edi, 0x20',
#     '19': 'mov esi, 0x41',
#     '20': 'movabs rdx, 0',
#     '21': 'mov al, 0',
#     '22': 'call 0x5d2850',
#     '23': 'mov dword ptr [rbp - 4], 0',
#     '24': 'jmp 0x4de94c',
#     '25': 'movabs rdi, 0x2800',
#     '26': 'lea rsi, [rip + 0x275bae]',
#     '27': 'mov edx, 0x42',
#     '28': 'call 0x61f410',
#     '29': 'mov rsi, qword ptr [rbp - 0x18]',
#     '30': 'mov qword ptr [rsi], rax',
#     '31': 'mov rax, qword ptr [rbp - 0x18]',
#     '32': 'cmp qword ptr [rax], 0',
#     '33': 'jne 0x4de90d',
#     '34': 'call 0x5d2650',
#     '35': 'lea rdi, [rip + 0x275b80]',
#     '36': 'mov esi, 0x44',
#     '37': 'lea rdx, [rip + 0x275b89]',
#     '38': 'call 0x5d2790',
#     '39': 'mov edi, 0x20',
#     '40': 'mov esi, 0x41',
#     '41': 'movabs rdx, 0',
#     '42': 'mov al, 0',
#     '43': 'call 0x5d2850',
#     '44': 'lea rsi, [rip + 0x275b4d]',
#     '45': 'mov edx, 0x45',
#     '46': 'mov rcx, qword ptr [rbp - 0x18]',
#     '47': 'mov rdi, rcx',
#     '48': 'call 0x61f600',
#     '49': 'mov rax, qword ptr [rbp - 0x18]',
#     '50': 'mov dword ptr [rax + 8], 0x2800',
#     '51': 'mov rax, qword ptr [rbp - 0x18]',
#     '52': 'mov dword ptr [rax + 0xc], 0',
#     '53': 'mov rax, qword ptr [rbp - 0x10]',
#     '54': 'mov dword ptr [rax + 0x20], 1',
#     '55': 'mov rax, qword ptr [rbp - 0x18]',
#     '56': 'mov rcx, qword ptr [rbp - 0x10]',
#     '57': 'mov qword ptr [rcx + 0x38], rax',
#     '58': 'mov rax, qword ptr [rbp - 0x10]',
#     '59': 'mov dword ptr [rax + 0x28], 0',
#     '60': 'mov dword ptr [rbp - 4], 1',
#     '61': 'mov eax, dword ptr [rbp - 4]',
#     '62': 'add rsp, 0x20',
#     '63': 'pop rbp',
#     '64': 'ret '}},
#   ...]}
