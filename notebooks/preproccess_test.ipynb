# %%
import sys
sys.path.append('..')  # Add parent directory

from utils.pre_proccess_util import PreProcessor

processor = PreProcessor()

# %%
processor.process_binary_dataset()
# Out:
# projects ['curl', 'unrar']
# project path ../data/test_dataset/curl
# filenames ['x64-clang-5.0-O1_curl', 'x64-clang-3.5-O1_curl', 'x64-clang-5.0-O2_curl']
# creating angr project for ../data/test_dataset/curl/x64-clang-5.0-O1_curl
# analysing cfg...
# took 2.1606099605560303 seconds to analyse cfg
# getting asm...
# took 2.7607390880584717 seconds to fully preprocess "x64-clang-5.0-O1_curl"
# [1/2] projects and [1/3] files done
# creating angr project for ../data/test_dataset/curl/x64-clang-3.5-O1_curl
# analysing cfg...
# took 2.4742109775543213 seconds to analyse cfg
# getting asm...
# took 3.1036458015441895 seconds to fully preprocess "x64-clang-3.5-O1_curl"
# [1/2] projects and [2/3] files done
# creating angr project for ../data/test_dataset/curl/x64-clang-5.0-O2_curl
# analysing cfg...
# took 2.5329031944274902 seconds to analyse cfg
# getting asm...
# took 3.2413558959960938 seconds to fully preprocess "x64-clang-5.0-O2_curl"
# [1/2] projects and [3/3] files done
# took 0.00012493133544921875 seconds filter out the duplicates
# project path ../data/test_dataset/unrar
# filenames ['x64-gcc-7-Os_unrar', 'x64-gcc-9-Os_unrar', 'x64-gcc-4.8-Os_unrar']
# creating angr project for ../data/test_dataset/unrar/x64-gcc-7-Os_unrar
# WARNING  | 2026-01-10 16:55:23,670 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: _ZTVN10__cxxabiv116__enum_type_infoE
# WARNING  | 2026-01-10 16:55:23,670 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: _ZTVN10__cxxabiv117__class_type_infoE
# WARNING  | 2026-01-10 16:55:23,670 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: _ZTVN10__cxxabiv120__si_class_type_infoE
# WARNING  | 2026-01-10 16:55:23,672 | cle.loader     | For more information about "Symbol was allocated without a known size",see https://docs.angr.io/extending-angr/environment#simdata
# analysing cfg...
# took 1.631392002105713 seconds to analyse cfg
# getting asm...
# took 2.043064832687378 seconds to fully preprocess "x64-gcc-7-Os_unrar"
# [2/2] projects and [1/3] files done
# creating angr project for ../data/test_dataset/unrar/x64-gcc-9-Os_unrar
# WARNING  | 2026-01-10 16:55:25,716 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: _ZTVN10__cxxabiv116__enum_type_infoE
# WARNING  | 2026-01-10 16:55:25,716 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: _ZTVN10__cxxabiv117__class_type_infoE
# WARNING  | 2026-01-10 16:55:25,716 | cle.backends.externs | Symbol was allocated without a known size; emulation may fail if it is used non-opaquely: _ZTVN10__cxxabiv120__si_class_type_infoE
# WARNING  | 2026-01-10 16:55:25,718 | cle.loader     | For more information about "Symbol was allocated without a known size",see https://docs.angr.io/extending-angr/environment#simdata
# analysing cfg...
# took 1.4862909317016602 seconds to analyse cfg
# getting asm...
# took 1.9307289123535156 seconds to fully preprocess "x64-gcc-9-Os_unrar"
# [2/2] projects and [2/3] files done
# creating angr project for ../data/test_dataset/unrar/x64-gcc-4.8-Os_unrar
# analysing cfg...
# took 1.4148411750793457 seconds to analyse cfg
# getting asm...
# took 1.815704107284546 seconds to fully preprocess "x64-gcc-4.8-Os_unrar"
# [2/2] projects and [3/3] files done
# took 8.606910705566406e-05 seconds filter out the duplicates
