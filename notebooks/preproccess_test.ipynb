# %%
import sys
sys.path.append('..')  # Add parent directory

from utils.pre_proccess_util import PreProcessor

processor = PreProcessor()

# %%
processor.process_bin()
# Out:
# __cxa_finalize
# puts
# strlen
# __stack_chk_fail
# strcspn
# fgets
# strcmp
# __memcpy_chk
# main
# 4198688
# 4198734
# 4198754
# 4198769
# 4198781
# 4198785
# 4198827
# 4198797
# 4198839
# 4198816
# 4198841
# ...
