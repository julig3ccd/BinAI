# %%
import sys
sys.path.append('..')  # Add parent directory

from utils.pre_proccess_util import PreProcessor

processor = PreProcessor()

# %%
processor.process_binary_dataset()
# Out:
# projects ['z3', 'zlib', 'curl', 'unrar', 'nmap', 'openssl', 'clamav']
# project path ../data/Dataset-1-X64/z3
# filenames ['x64-clang-7-O2_z3', 'x64-clang-9-O1_z3', 'x64-gcc-9-O0_z3', 'x64-gcc-7-O3_z3', 'x64-clang-5.0-O1_z3', 'x64-clang-3.5-O3_z3', 'x64-gcc-5-O3_z3', 'x64-clang-3.5-O2_z3', 'x64-gcc-5-O2_z3', 'x64-clang-7-O3_z3', 'x64-clang-9-O0_z3', 'x64-gcc-9-O1_z3', 'x64-gcc-7-O2_z3', 'x64-clang-5.0-O0_z3', 'x64-clang-7-Os_z3', 'x64-gcc-4.8-O0_z3', 'x64-gcc-7-Os_z3', 'x64-gcc-4.8-O1_z3', 'x64-gcc-5-Os_z3', 'x64-clang-3.5-Os_z3', 'x64-gcc-9-Os_z3', 'x64-gcc-4.8-O2_z3', 'x64-clang-9-Os_z3', 'x64-clang-5.0-Os_z3', 'x64-gcc-4.8-O3_z3', 'x64-clang-3.5-O1_z3', 'x64-gcc-5-O1_z3', 'x64-clang-9-O3_z3', 'x64-clang-7-O0_z3', 'x64-gcc-7-O1_z3', 'x64-gcc-9-O2_z3', 'x64-gcc-4.8-Os_z3', 'x64-clang-5.0-O3_z3', 'x64-clang-9-O2_z3', 'x64-clang-7-O1_z3', 'x64-gcc-7-O0_z3', 'x64-gcc-9-O3_z3', 'x64-clang-5.0-O2_z3', 'x64-clang-3.5-O0_z3', 'x64-gcc-5-O0_z3']
# creating angr project for ../data/Dataset-1-X64/z3/x64-clang-7-O2_z3
# analysing cfg...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 processor.process_binary_dataset()
#
# File ~/GitHub/BinAI/notebooks/../utils/pre_proccess_util.py:151, in PreProcessor.process_binary_dataset(self, dataset_path, output_path)
#     149 print(f'filenames {filenames}')
#     150 for f_idx, filename in enumerate(filenames):
# --> 151     file_asm=self.process_binary_file(f'{project_path}/{filename}')
#     152     proj_data.append(file_asm)
#     153     print(f'[{p_idx+1}/{len(projects)}] projects and [{f_idx+1}/{len(filenames)}] files done', flush=True)
#
# File ~/GitHub/BinAI/notebooks/../utils/pre_proccess_util.py:112, in PreProcessor.process_binary_file(self, binary_path, dump_json)
#     110 print("analysing cfg...", flush=True)
#     111 start_cfg_analyis= time.time()
# --> 112 cfg = proj.analyses.CFGFast( normalize=False,
#     113                              resolve_indirect_jumps=False,
#     114                              data_references=False,
#     115                              cross_references=False,
#     116                              force_complete_scan=False,
#     117                              force_smart_scan=False)
#     118 end_cfg_analysis=time.time()
#     119 print(f'took {end_cfg_analysis-start_cfg_analyis} seconds to analyse cfg')
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/analysis.py:216, in AnalysisFactory.__call__(self, *args, **kwargs)
#     210 show_progressbar = kwargs.pop("show_progressbar", False)
#     212 w = self.prep(
#     213     fail_fast=fail_fast, kb=kb, progress_callback=progress_callback, show_progressbar=show_progressbar
#     214 )
# --> 216 r = w(*args, **kwargs)
#     217 # clean up so that it's always pickleable
#     218 r._progressbar = None
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/analysis.py:201, in AnalysisFactory.prep.<locals>.wrapper(*args, **kwargs)
#     198 oself._progress_callback = progress_callback
#     200 oself._show_progressbar = show_progressbar
# --> 201 oself.__init__(*args, **kwargs)
#     202 return oself
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/cfg/cfg_fast.py:844, in CFGFast.__init__(self, binary, objects, regions, pickle_intermediate_results, symbols, function_prologues, resolve_indirect_jumps, force_segment, force_smart_scan, force_complete_scan, indirect_jump_target_limit, data_references, cross_references, normalize, start_at_entry, function_starts, extra_memory_regions, data_type_guessing_handlers, arch_options, indirect_jump_resolvers, base_state, exclude_sparse_regions, skip_specific_regions, heuristic_plt_resolving, detect_tail_calls, low_priority, cfb, model, elf_eh_frame, exceptions, skip_unmapped_addrs, nodecode_window_size, nodecode_threshold, nodecode_step, indirect_calls_always_return, jumptable_resolver_resolves_calls, start, end, collect_data_references, extra_cross_references, **extra_arch_options)
#     835 self._decoding_assumption_relations = None
#     837 # A mapping between address and the actual data in memory
#     838 # self._memory_data = { }
#     839 # A mapping between address of the instruction that's referencing the memory data and the memory data itself
#    (...)
#     842
#     843 # Start working!
# --> 844 self._analyze()
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/forward_analysis/forward_analysis.py:261, in ForwardAnalysis._analyze(self)
#     254 self._pre_analysis()
#     256 if self._graph_visitor is None:
#     257     # There is no base graph that we can rely on. The analysis itself should generate successors for the
#     258     # current job.
#     259     # An example is the CFG recovery.
# --> 261     self._analysis_core_baremetal()
#     263 else:
#     264     # We have a base graph to follow. Just handle the current job.
#     266     self._analysis_core_graph()
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/forward_analysis/forward_analysis.py:404, in ForwardAnalysis._analysis_core_baremetal(self)
#     401 self._job_map.pop(self._job_key(job_info.job), None)
#     402 self._job_info_queue.pop(0)
# --> 404 self._process_job_and_get_successors(job_info)
#     406 # Short-cut for aborting the analysis
#     407 if self.should_abort:
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/forward_analysis/forward_analysis.py:422, in ForwardAnalysis._process_job_and_get_successors(self, job_info)
#     413 """
#     414 Process a job, get all successors of this job, and call _handle_successor() to handle each successor.
#     415
#     416 :param JobInfo job_info: The JobInfo instance
#     417 :return: None
#     418 """
#     420 job = job_info.job
# --> 422 successors = self._get_successors(job)
#     424 all_new_jobs = []
#     426 for successor in successors:
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/cfg/cfg_fast.py:1341, in CFGFast._get_successors(self, job)
#    1332 def _get_successors(self, job: CFGJob) -> List[CFGJob]:  # type: ignore[override] # pylint:disable=arguments-differ
#    1333     # current_function_addr = job.func_addr
#    1334     # addr = job.addr
#    (...)
#    1338     # else:
#    1339     #    l.debug("Tracing new exit %#x", addr)
# -> 1341     jobs = self._scan_block(job)
#    1343     # l.debug("... got %d jobs: %s", len(jobs), jobs)
#    1345     job_: CFGJob
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/cfg/cfg_fast.py:1888, in CFGFast._scan_block(self, cfg_job)
#    1885     entries = self._scan_procedure(cfg_job, current_func_addr)
#    1887 else:
# -> 1888     entries = self._scan_irsb(cfg_job, current_func_addr)
#    1890 return entries
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/cfg/cfg_fast.py:2091, in CFGFast._scan_irsb(self, cfg_job, current_func_addr)
#    2088 if self.project.arch.name in {"MIPS32", "MIPS64"}:
#    2089     # the caller might have gp passed on
#    2090     caller_gp = cfg_job.gp
# -> 2091 self._process_block_arch_specific(addr, cfg_node, irsb, function_addr, caller_gp=caller_gp)
#    2093 # Scan the basic block to collect data references
#    2094 if self._collect_data_ref:
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/analyses/cfg/cfg_fast.py:4681, in CFGFast._process_block_arch_specific(self, addr, cfg_node, irsb, func_addr, caller_gp)
#    4678 cap = self._lift(addr, size=cfg_node.size).capstone
#    4679 for insn in cap.insns:
#    4680     if (
# -> 4681         insn.mnemonic == "mov"
#    4682         and len(insn.operands) == 2
#    4683         and insn.operands[0].type == capstone.x86.X86_OP_REG
#    4684         and insn.operands[1].type == capstone.x86.X86_OP_REG
#    4685     ):
#    4686         if (
#    4687             insn.operands[0].reg == capstone.x86.X86_REG_RBP
#    4688             and insn.operands[1].reg == capstone.x86.X86_REG_RSP
#    4689         ):
#    4690             rbp_as_gpr = False
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/block.py:106, in CapstoneInsn.mnemonic(self)
#     104 @property
#     105 def mnemonic(self) -> str:
# --> 106     return self.insn.mnemonic
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/__init__.py:667, in CsInsn.mnemonic(self)
#     663 if self._cs._diet:
#     664     # Diet engine cannot provide @mnemonic.
#     665     raise CsError(CS_ERR_DIET)
# --> 667 return self._raw.mnemonic.decode('ascii')
#
# KeyboardInterrupt:
