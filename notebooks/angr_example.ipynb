# %%
import angr
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import angr
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/__init__.py:46
#      43 import_fake_pkg_resources(force=False)
#      45 # this must happen first, prior to initializing analyses
# ---> 46 from .sim_procedure import SimProcedure
#      47 from .procedures import SIM_PROCEDURES, SimProcedures, SIM_LIBRARIES, SIM_TYPE_COLLECTIONS
#      49 from . import sim_options
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/angr/sim_procedure.py:8
#       5 from typing import TYPE_CHECKING, Union, Tuple
#       7 import claripy
# ----> 8 from cle import SymbolType
#       9 from archinfo.arch_soot import SootAddressDescriptor
#      11 if TYPE_CHECKING:
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/cle/__init__.py:11
#       8 __version__ = "9.2.102"
#      10 from .address_translator import AT, AddressTranslator
# ---> 11 from .backends import (
#      12     ALL_BACKENDS,
#      13     CGC,
#      14     ELF,
#      15     PE,
#      16     TE,
#      17     XBE,
#      18     Apk,
#      19     BackedCGC,
#      20     Backend,
#      21     Blob,
#      22     Coff,
#      23     ELFCore,
#      24     ExceptionHandling,
#      25     FunctionHint,
#      26     FunctionHintSource,
#      27     Hex,
#      28     Jar,
#      29     MachO,
#      30     MetaELF,
#      31     Minidump,
#      32     NamedRegion,
#      33     Region,
#      34     Regions,
#      35     Section,
#      36     Segment,
#      37     Soot,
#      38     SRec,
#      39     StaticArchive,
#      40     Symbol,
#      41     SymbolSubType,
#      42     SymbolType,
#      43     UefiFirmware,
#      44     register_backend,
#      45 )
#      46 from .backends.externs import (
#      47     ExternObject,
#      48     ExternSegment,
#    (...)
#      51     TOCRelocation,
#      52 )
#      53 from .backends.tls import (
#      54     ELFCoreThreadManager,
#      55     ELFThreadManager,
#    (...)
#      60     TLSObject,
#      61 )
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/cle/backends/__init__.py:1
# ----> 1 from .backend import ALL_BACKENDS, Backend, ExceptionHandling, FunctionHint, FunctionHintSource, register_backend
#       2 from .blob import Blob
#       3 from .cgc import CGC, BackedCGC
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/cle/backends/backend.py:8
#       5 from io import BufferedReader
#       6 from typing import TYPE_CHECKING, Any, BinaryIO, Dict, List, Optional, Type, Union
# ----> 8 import archinfo
#       9 import sortedcontainers
#      11 from cle.address_translator import AT
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/archinfo/__init__.py:10
#       2 """
#       3 archinfo is a collection of classes that contain architecture-specific information.
#       4 It is useful for cross-architecture tools (such as pyvex).
#       5 """
#       7 __version__ = "9.2.102"
# ---> 10 from .arch import (
#      11     Arch,
#      12     ArchNotFound,
#      13     Register,
#      14     all_arches,
#      15     arch_from_id,
#      16     get_host_arch,
#      17     register_arch,
#      18     reverse_ends,
#      19 )
#      20 from .arch_aarch64 import ArchAArch64
#      21 from .arch_amd64 import ArchAMD64
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/archinfo/arch.py:28
#      25     _unicorn = None
#      27 try:
# ---> 28     import capstone as _capstone
#      29 except ImportError:
#      30     _capstone = None
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/__init__.py:372
#     370 for _path in _path_list:
#     371     if _path is None: continue
# --> 372     _cs = _load_lib(_path)
#     373     if _cs is not None: break
#     374 else:
#
# File ~/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/__init__.py:345, in _load_lib(path)
#     343 lib_file = join(path, _lib)
#     344 if os.path.exists(lib_file):
# --> 345     return ctypes.cdll.LoadLibrary(lib_file)
#     346 else:
#     347     # if we're on linux, try again with .so.5 extension
#     348     if lib_file.endswith('.so'):
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py:444, in LibraryLoader.LoadLibrary(self, name)
#     443 def LoadLibrary(self, name):
# --> 444     return self._dlltype(name)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ctypes/__init__.py:366, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     363 self._FuncPtr = _FuncPtr
#     365 if handle is None:
# --> 366     self._handle = _dlopen(self._name, mode)
#     367 else:
#     368     self._handle = handle
#
# OSError: dlopen(/Users/juliangeissinger/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/lib/libcapstone.dylib, 0x0006): tried: '/Users/juliangeissinger/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/lib/libcapstone.dylib' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64e' or 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/juliangeissinger/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/lib/libcapstone.dylib' (no such file), '/Users/juliangeissinger/GitHub/BinAI/binai_venv/lib/python3.9/site-packages/capstone/lib/libcapstone.dylib' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64e' or 'arm64'))

# %% [markdown]
# # Demo: quick angr pipeline
# **Goal:** show key angr features end-to-end:
# 1. load binary & project
# 2. build CFG (fast)
# 3. traverse CFG -> per-instruction disassembly (mnemonic + operands)
# 4. inspect VEX IR for a block
# 5. tiny symbolic execution: set symbolic input & find target

# %%
# the path for the binary to be analyzed
BINARY_PATH = "../data/bound_vuln_stripped"

# %% [markdown]
# ## 1) Load an angr project & some quick checks:

# %%
proj_stripped = angr.Project(BINARY_PATH, auto_load_libs=False)
print("Arch:", proj_stripped.arch)
print("Entry:", hex(proj_stripped.entry))
print("Base:", hex(proj_stripped.loader.main_object.mapped_base))
print("Sections:", [ (s.name, hex(s.min_addr), hex(s.max_addr)) for s in proj_stripped.loader.main_object.sections ])
syms_stripped = proj_stripped.loader.main_object.symbols
# Out:
# Arch: <Arch AMD64 (LE)>
# Entry: 0x4011c0
# Base: 0x400000
# Sections: [('', '0x400000', '0x3fffff'), ('.interp', '0x400318', '0x400333'), ('.note.gnu.property', '0x400338', '0x400367'), ('.note.gnu.build-id', '0x400368', '0x40038b'), ('.note.ABI-tag', '0x40038c', '0x4003ab'), ('.gnu.hash', '0x4003b0', '0x4003d7'), ('.dynsym', '0x4003d8', '0x400527'), ('.dynstr', '0x400528', '0x40060a'), ('.gnu.version', '0x40060c', '0x400627'), ('.gnu.version_r', '0x400628', '0x400677'), ('.rela.dyn', '0x400678', '0x40074f'), ('.rela.plt', '0x400750', '0x4007f7'), ('.init', '0x401000', '0x40101a'), ('.plt', '0x401020', '0x40109f'), ('.plt.got', '0x4010a0', '0x4010af'), ('.plt.sec', '0x4010b0', '0x40111f'), ('.text', '0x401120', '0x40131b'), ('.fini', '0x40131c', '0x401328'), ('.rodata', '0x402000', '0x40201f'), ('.eh_frame_hdr', '0x402020', '0x40205b'), ('.eh_frame', '0x402060', '0x402133'), ('.init_array', '0x403d88', '0x403d8f'), ('.fini_array', '0x403d90', '0x403d97'), ('.dynamic', '0x403d98', '0x403f87'), ('.got', '0x403f88', '0x403fff'), ('.data', '0x404000', '0x40400f'), ('.bss', '0x404010', '0x40401f'), ('.comment', '0x400000', '0x40002a'), ('.shstrtab', '0x400000', '0x400109')]

# %%
BINARY_PATH = "../data/bound_vuln"
proj = angr.Project(BINARY_PATH, auto_load_libs=False)
section_syms = [s.name for s in proj_stripped.loader.main_object.sections]
section = [s.name for s in proj.loader.main_object.sections]
print(set(section) - set(section_syms))
main_symbol = proj.loader.main_object.get_symbol("main")
print (hex(main_symbol.rebased_addr))
main_symbol = proj.loader.main_object.symbols_by_addr[int('0x401120', 16)]
print(main_symbol.name)
# Out:
# CRITICAL | 2025-11-17 17:31:44,494 | cle.backends.backend | Deprecation warning: symbols_by_addr is deprecated - use loader.find_symbol() for lookup and .symbols for enumeration
# {'.strtab', '.symtab'}
# 0x401120
# main

# %% [markdown]
# ## 2) Build a CFG (fast)

# %%
cfg = proj.analyses.CFGFast(normalize=True)
funcs = list(cfg.kb.functions.items())
for addr, func in funcs:
    print(f"  {func.name:40} -> {hex(addr)}")
if "main" in cfg.kb.functions:
    main_addr = cfg.kb.functions["main"].addr
    print(hex(main_addr))
# Out:
#   _init                                    -> 0x401000
#   sub_401020                               -> 0x401020
#   sub_40102d                               -> 0x40102d
#   sub_401030                               -> 0x401030
#   sub_40103f                               -> 0x40103f
#   sub_401040                               -> 0x401040
#   sub_40104f                               -> 0x40104f
#   sub_401050                               -> 0x401050
#   sub_40105f                               -> 0x40105f
#   sub_401060                               -> 0x401060
#   sub_40106f                               -> 0x40106f
#   sub_401070                               -> 0x401070
#   sub_40107f                               -> 0x40107f
#   sub_401080                               -> 0x401080
#   sub_40108f                               -> 0x40108f
#   sub_401090                               -> 0x401090
#   sub_40109f                               -> 0x40109f
#   __cxa_finalize                           -> 0x4010a0
#   puts                                     -> 0x4010b0
#   strlen                                   -> 0x4010c0
#   __stack_chk_fail                         -> 0x4010d0
#   strcspn                                  -> 0x4010e0
#   fgets                                    -> 0x4010f0
#   strcmp                                   -> 0x401100
#   __memcpy_chk                             -> 0x401110
#   main                                     -> 0x401120
#   sub_4011be                               -> 0x4011be
#   _start                                   -> 0x4011c0
#   sub_4011e5                               -> 0x4011e5
#   sub_4011e6                               -> 0x4011e6
#   deregister_tm_clones                     -> 0x4011f0
#   sub_401219                               -> 0x401219
#   register_tm_clones                       -> 0x401220
#   sub_401259                               -> 0x401259
#   __do_global_dtors_aux                    -> 0x401260
#   sub_401295                               -> 0x401295
#   sub_401299                               -> 0x401299
#   frame_dummy                              -> 0x4012a0
#   sub_4012a9                               -> 0x4012a9
#   check                                    -> 0x4012b0
#   _fini                                    -> 0x40131c
#   __libc_start_main                        -> 0x500000
#   puts                                     -> 0x500010
#   strlen                                   -> 0x500018
#   __stack_chk_fail                         -> 0x500020
#   strcspn                                  -> 0x500028
#   fgets                                    -> 0x500030
#   strcmp                                   -> 0x500038
#   __memcpy_chk                             -> 0x500040
#   UnresolvableJumpTarget                   -> 0x601050
#   UnresolvableCallTarget                   -> 0x601058
# 0x401120

# %% [markdown]
# ## 3) Traverse the CFG: iterate blocks in `main`, extract disasm, opcode & operands
# **For each block**: we get capstone disassembly if available (`block.capstone`) and per-insn fields:
# - `insn.mnemonic` and `insn.op_str`
# - raw bytes: `insn.bytes`

# %%
for func_addr, func in cfg.functions.items():
    if func.name.startswith('sub_') or func.name in ['UnresolvableCallTarget', 'UnresolvableJumpTarget']:
        continue
    print(func.name)
    if(func.name!="main"):
        continue
    for block in func.blocks:
        block_addr = block.addr
        print(block_addr)
        #disassemble instructions from block
        disassembly = block.capstone.insns
        records = []
        #build record of instructions for binary file
        for insn in disassembly:
            #TODO build actual tokenizer input (e.g. string, or string[])
            records.append({
                "addr": hex(insn.address),
                "mnemonic": insn.mnemonic,
                "op_str": insn.op_str,
                "bytes": insn.bytes.hex()
            })
        print(records)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 for func_addr, func in cfg.functions.items():
#       2     if func.name.startswith('sub_') or func.name in ['UnresolvableCallTarget', 'UnresolvableJumpTarget']:
#       3         continue
#
# NameError: name 'cfg' is not defined

# %% [markdown]
# ## 4) Inspect VEX IR for a block
# angr exposes PyVEX `IRSBB` via `block.vex` (or `block.vex.pp()` text)

# %%
main_function = cfg.functions[main_addr]
for block in main_function.blocks:
    print("VEX IR (short):")
    print(block.vex.pp())

    # Or iterate VEX statements
    stmts = block.vex.statements
    print("\nStatements count:", len(stmts))
    for s in stmts:
        print(" -", s)  
    break
# Out:
# VEX IR (short):
# IRSB {
#    t0:Ity_I64 t1:Ity_I64 t2:Ity_I64 t3:Ity_I64 t4:Ity_I64 t5:Ity_I64 t6:Ity_I64 t7:Ity_I64 t8:Ity_I32 t9:Ity_I32 t10:Ity_I32 t11:Ity_I64 t12:Ity_I64 t13:Ity_I64 t14:Ity_I64 t15:Ity_I64 t16:Ity_I64 t17:Ity_I64 t18:Ity_I64 t19:Ity_I64 t20:Ity_I64 t21:Ity_I64 t22:Ity_I32 t23:Ity_I64 t24:Ity_I32 t25:Ity_I64 t26:Ity_I64 t27:Ity_I64 t28:Ity_I64 t29:Ity_I64 t30:Ity_I64 t31:Ity_I64 t32:Ity_I64
#
#    00 | ------ IMark(0x401120, 4, 0) ------
#    01 | PUT(rip) = 0x0000000000401124
#    02 | ------ IMark(0x401124, 1, 0) ------
#    03 | t0 = GET:I64(rbp)
#    04 | t14 = GET:I64(rsp)
#    05 | t13 = Sub64(t14,0x0000000000000008)
#    06 | PUT(rsp) = t13
#    07 | STle(t13) = t0
#    08 | ------ IMark(0x401125, 7, 0) ------
#    09 | PUT(rdi) = 0x000000000040200b
#    10 | ------ IMark(0x40112c, 7, 0) ------
#    11 | t3 = Sub64(t13,0x0000000000000090)
#    12 | PUT(rsp) = t3
#    13 | PUT(rip) = 0x0000000000401133
#    14 | ------ IMark(0x401133, 9, 0) ------
#    15 | t16 = GET:I64(fs)
#    16 | t15 = Add64(0x0000000000000028,t16)
#    17 | t17 = LDle:I64(t15)
#    18 | PUT(rip) = 0x000000000040113c
#    19 | ------ IMark(0x40113c, 8, 0) ------
#    20 | t18 = Add64(t3,0x0000000000000088)
#    21 | STle(t18) = t17
#    22 | ------ IMark(0x401144, 2, 0) ------
#    23 | PUT(cc_op) = 0x0000000000000013
#    24 | PUT(cc_dep1) = 0x0000000000000000
#    25 | PUT(cc_dep2) = 0x0000000000000000
#    26 | PUT(rax) = 0x0000000000000000
#    27 | ------ IMark(0x401146, 3, 0) ------
#    28 | PUT(rbp) = t3
#    29 | PUT(rip) = 0x0000000000401149
#    30 | ------ IMark(0x401149, 5, 0) ------
#    31 | t29 = Sub64(t3,0x0000000000000008)
#    32 | PUT(rsp) = t29
#    33 | STle(t29) = 0x000000000040114e
#    34 | t31 = Sub64(t29,0x0000000000000080)
#    35 | ====== AbiHint(0xt31, 128, 0x00000000004010b0) ======
#    NEXT: PUT(rip) = 0x00000000004010b0; Ijk_Call
# }
# None
#
# Statements count: 36
#  - ------ IMark(0x401120, 4, 0) ------
#  - PUT(offset=184) = 0x0000000000401124
#  - ------ IMark(0x401124, 1, 0) ------
#  - t0 = GET:I64(offset=56)
#  - t14 = GET:I64(offset=48)
#  - t13 = Sub64(t14,0x0000000000000008)
#  - PUT(offset=48) = t13
#  - STle(t13) = t0
#  - ------ IMark(0x401125, 7, 0) ------
#  - PUT(offset=72) = 0x000000000040200b
#  - ------ IMark(0x40112c, 7, 0) ------
#  - t3 = Sub64(t13,0x0000000000000090)
#  - PUT(offset=48) = t3
#  - PUT(offset=184) = 0x0000000000401133
#  - ------ IMark(0x401133, 9, 0) ------
#  - t16 = GET:I64(offset=208)
#  - t15 = Add64(0x0000000000000028,t16)
#  - t17 = LDle:I64(t15)
#  - PUT(offset=184) = 0x000000000040113c
#  - ------ IMark(0x40113c, 8, 0) ------
#  - t18 = Add64(t3,0x0000000000000088)
#  - STle(t18) = t17
#  - ------ IMark(0x401144, 2, 0) ------
#  - PUT(offset=144) = 0x0000000000000013
#  - PUT(offset=152) = 0x0000000000000000
#  - PUT(offset=160) = 0x0000000000000000
#  - PUT(offset=16) = 0x0000000000000000
#  - ------ IMark(0x401146, 3, 0) ------
#  - PUT(offset=56) = t3
#  - PUT(offset=184) = 0x0000000000401149
#  - ------ IMark(0x401149, 5, 0) ------
#  - t29 = Sub64(t3,0x0000000000000008)
#  - PUT(offset=48) = t29
#  - STle(t29) = 0x000000000040114e
#  - t31 = Sub64(t29,0x0000000000000080)
#  - ====== AbiHint(0xt31, 128, 0x00000000004010b0) ======

# %% [markdown]
# ## 5) Simple data-flow: Symbolic Execution to trace the value in specific registers

# %%
# define the hook for fgets
class MyFgets(angr.SimProcedure):
    def run(self, s, size, stream):
        data = b"secret\x00"
        bv = claripy.BVV(data)
        self.state.memory.store(s, bv)
        return s

# # Hook commonly used libc symbols
proj.hook_symbol("puts", angr.SIM_PROCEDURES['libc']['puts']())
proj.hook_symbol("strlen", angr.SIM_PROCEDURES['libc']['strlen']())
proj.hook_symbol("strcmp", angr.SIM_PROCEDURES['libc']['strcmp']())
# proj.hook_symbol("fgets", angr.SIM_PROCEDURES['libc']['fgets']())
proj.hook_symbol("fgets", MyFgets())
proj.hook_symbol("__memcpy_chk", angr.SIM_PROCEDURES['libc']['memcpy']())

# // bound_vuln.c
# #include <stdio.h>
# #include <string.h>

# int check(const char* in){
#     char buf[16];
#     if (strlen(in) <= 32) {
#         strcpy(buf, in);
#         return strcmp(buf, "secret");
#     }
#     return -1;
# }
# int main(){
#     char input[128];
#     puts("Enter token:");
#     fgets(input, sizeof(input), stdin);
#     input[strcspn(input, "\n")] = 0;
#     if (check(input)==0) puts("OK");
#     else puts("NO");
#     return 0;
# }

func = next(cfg.functions.get_by_name("main"))

# the entry for symbolic execution
state = proj.factory.blank_state(addr=func.addr)

# define rdi as a symbol
import claripy
rdi_sym = claripy.BVS("rdi_sym", 64)
state.regs.rdi = rdi_sym

# create the symbolic execution manager
simgr = proj.factory.simgr(state)

# execute step by step
for step in range(200):
    if len(simgr.active) == 0:
        print("No more active states.")
        break
    
    state = simgr.active[0]
    print("RDI =", state.solver.eval_upto(state.regs.rdi, 1))
    print("RDI (AST) =", state.regs.rdi)
    print(f"\n--- Step {step}, PC = {hex(state.addr)} ---")
    if((state.addr)==int("0x4011ab", 16)):
        print("hell no")
        break
    if((state.addr)==int("0x401181", 16)):
        print("Oh yes")
        break
    try:
        block = proj.factory.block(state.addr)
        print(block.disassembly)
    except:
        pass

    # one step further
    simgr.step()
# Out:
# WARNING  | 2025-11-17 17:31:44,645 | angr.project   | Address is already hooked, during hook(0x500010, <SimProcedure puts>). Re-hooking.
# WARNING  | 2025-11-17 17:31:44,645 | angr.project   | Address is already hooked, during hook(0x500018, <SimProcedure strlen>). Re-hooking.
# WARNING  | 2025-11-17 17:31:44,646 | angr.project   | Address is already hooked, during hook(0x500038, <SimProcedure strcmp>). Re-hooking.
# WARNING  | 2025-11-17 17:31:44,647 | angr.project   | Address is already hooked, during hook(0x500030, <SimProcedure MyFgets>). Re-hooking.
# WARNING  | 2025-11-17 17:31:44,647 | angr.project   | Address is already hooked, during hook(0x500040, <SimProcedure memcpy>). Re-hooking.
# WARNING  | 2025-11-17 17:31:44,676 | angr.storage.memory_mixins.default_filler_mixin | The program is accessing register with an unspecified value. This could indicate unwanted behavior.
# WARNING  | 2025-11-17 17:31:44,676 | angr.storage.memory_mixins.default_filler_mixin | angr will cope with this by generating an unconstrained symbolic variable and continuing. You can resolve this by:
# WARNING  | 2025-11-17 17:31:44,676 | angr.storage.memory_mixins.default_filler_mixin | 1) setting a value to the initial state
# WARNING  | 2025-11-17 17:31:44,676 | angr.storage.memory_mixins.default_filler_mixin | 2) adding the state option ZERO_FILL_UNCONSTRAINED_{MEMORY,REGISTERS}, to make unknown regions hold null
# WARNING  | 2025-11-17 17:31:44,677 | angr.storage.memory_mixins.default_filler_mixin | 3) adding the state option SYMBOL_FILL_UNCONSTRAINED_{MEMORY,REGISTERS}, to suppress these messages.
# WARNING  | 2025-11-17 17:31:44,677 | angr.storage.memory_mixins.default_filler_mixin | Filling register rbp with 8 unconstrained bytes referenced from 0x401124 (main+0x4 in bound_vuln (0x1124))
# RDI = [0]
# RDI (AST) = <BV64 rdi_sym_5_64>
#
# --- Step 0, PC = 0x401120 ---
# 0x401120:	endbr64
# 0x401124:	push	rbp
# 0x401125:	lea	rdi, [rip + 0xedf]
# 0x40112c:	sub	rsp, 0x90
# 0x401133:	mov	rax, qword ptr fs:[0x28]
# 0x40113c:	mov	qword ptr [rsp + 0x88], rax
# 0x401144:	xor	eax, eax
# 0x401146:	mov	rbp, rsp
# 0x401149:	call	0x4010b0
# RDI = [4202507]
# RDI (AST) = <BV64 0x40200b>
#
# --- Step 1, PC = 0x4010b0 ---
# 0x4010b0:	endbr64
# 0x4010b4:	bnd jmp	qword ptr [rip + 0x2ee5]
# RDI = [4202507]
# RDI (AST) = <BV64 0x40200b>
#
# --- Step 2, PC = 0x500010 ---
# 0x500010:	add	byte ptr [rax], al
# 0x500012:	add	byte ptr [rax], al
# 0x500014:	add	byte ptr [rax], al
# 0x500016:	add	byte ptr [rax], al
# RDI = [4202507]
# RDI (AST) = <BV64 0x40200b>
#
# --- Step 3, PC = 0x40114e ---
# 0x40114e:	mov	rdx, qword ptr [rip + 0x2ebb]
# 0x401155:	mov	esi, 0x80
# 0x40115a:	mov	rdi, rbp
# 0x40115d:	call	0x4010f0
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 4, PC = 0x4010f0 ---
# 0x4010f0:	endbr64
# 0x4010f4:	bnd jmp	qword ptr [rip + 0x2ec5]
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 5, PC = 0x500030 ---
# WARNING  | 2025-11-17 17:31:44,767 | angr.storage.memory_mixins.default_filler_mixin | Filling memory at 0x7fffffffffeff6f with 122 unconstrained bytes referenced from 0x500018 (strlen+0x0 in extern-address space (0x18))
# WARNING  | 2025-11-17 17:31:44,780 | angr.storage.memory_mixins.default_filler_mixin | Filling memory at 0x7fffffffffeff3f with 17 unconstrained bytes referenced from 0x500038 (strcmp+0x0 in extern-address space (0x38))
# 0x500030:	add	byte ptr [rax], al
# 0x500032:	add	byte ptr [rax], al
# 0x500034:	add	byte ptr [rax], al
# 0x500036:	add	byte ptr [rax], al
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 6, PC = 0x401162 ---
# 0x401162:	mov	rdi, rbp
# 0x401165:	lea	rsi, [rip + 0xeac]
# 0x40116c:	call	0x4010e0
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 7, PC = 0x4010e0 ---
# 0x4010e0:	endbr64
# 0x4010e4:	bnd jmp	qword ptr [rip + 0x2ecd]
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 8, PC = 0x500028 ---
# 0x500028:	add	byte ptr [rax], al
# 0x50002a:	add	byte ptr [rax], al
# 0x50002c:	add	byte ptr [rax], al
# 0x50002e:	add	byte ptr [rax], al
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 9, PC = 0x401171 ---
# 0x401171:	mov	rdi, rbp
# 0x401174:	mov	byte ptr [rsp + rax], 0
# 0x401178:	call	0x4012b0
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 10, PC = 0x4012b0 ---
# 0x4012b0:	endbr64
# 0x4012b4:	push	rbp
# 0x4012b5:	mov	rbp, rdi
# 0x4012b8:	sub	rsp, 0x20
# 0x4012bc:	mov	rax, qword ptr fs:[0x28]
# 0x4012c5:	mov	qword ptr [rsp + 0x18], rax
# 0x4012ca:	xor	eax, eax
# 0x4012cc:	call	0x4010c0
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 11, PC = 0x4010c0 ---
# 0x4010c0:	endbr64
# 0x4010c4:	bnd jmp	qword ptr [rip + 0x2edd]
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 12, PC = 0x500018 ---
# 0x500018:	add	byte ptr [rax], al
# 0x50001a:	add	byte ptr [rax], al
# 0x50001c:	add	byte ptr [rax], al
# 0x50001e:	add	byte ptr [rax], al
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 13, PC = 0x4012d1 ---
# 0x4012d1:	cmp	rax, 0x20
# 0x4012d5:	ja	0x401310
# RDI = [576460752303357800]
# RDI (AST) = <BV64 0x7fffffffffeff68>
#
# --- Step 14, PC = 0x4012d7 ---
# 0x4012d7:	mov	rdi, rsp
# 0x4012da:	mov	rsi, rbp
# 0x4012dd:	lea	rdx, [rax + 1]
# 0x4012e1:	mov	ecx, 0x10
# 0x4012e6:	call	0x401110
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 15, PC = 0x401110 ---
# 0x401110:	endbr64
# 0x401114:	bnd jmp	qword ptr [rip + 0x2eb5]
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 16, PC = 0x500040 ---
# 0x500040:	add	byte ptr [rax], al
# 0x500042:	add	byte ptr [rax], al
# 0x500044:	add	byte ptr [rax], al
# 0x500046:	add	byte ptr [rax], al
# 0x500048:	mov	byte ptr [rax], ah
# 0x50004a:	lodsd	eax, dword ptr [rsi]
# 0x50004b:	sti
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 17, PC = 0x4012eb ---
# 0x4012eb:	lea	rsi, [rip + 0xd12]
# 0x4012f2:	mov	rdi, rax
# 0x4012f5:	call	0x401100
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 18, PC = 0x401100 ---
# 0x401100:	endbr64
# 0x401104:	bnd jmp	qword ptr [rip + 0x2ebd]
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 19, PC = 0x500038 ---
# 0x500038:	add	byte ptr [rax], al
# 0x50003a:	add	byte ptr [rax], al
# 0x50003c:	add	byte ptr [rax], al
# 0x50003e:	add	byte ptr [rax], al
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 20, PC = 0x4012fa ---
# 0x4012fa:	mov	rdx, qword ptr [rsp + 0x18]
# 0x4012ff:	sub	rdx, qword ptr fs:[0x28]
# 0x401308:	jne	0x401317
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 21, PC = 0x40130a ---
# 0x40130a:	add	rsp, 0x20
# 0x40130e:	pop	rbp
# 0x40130f:	ret
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 22, PC = 0x40117d ---
# 0x40117d:	test	eax, eax
# 0x40117f:	jne	0x4011ab
# RDI = [576460752303357752]
# RDI (AST) = <BV64 0x7fffffffffeff38>
#
# --- Step 23, PC = 0x401181 ---
# Oh yes
