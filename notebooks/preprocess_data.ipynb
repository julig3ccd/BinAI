# %%
import sys
sys.path.append('..')  # Add parent directory

from utils.pre_proccess_util import PreProcessor
#detect similar fcts for Test set
processor = PreProcessor(detect_similar_fct=True)

# %%
processor.process_binary_dataset()

# %%
from utils.build_fct_pools import Pool_Util
test_projects = ["zlib.json","unrar.json"]
num_samples=100
min_variants=4
data_dir="../data/PreProcessed_Data/test_set"
pooler = Pool_Util()
pooler.create_pools(data_dir=data_dir,
                    num_samples=num_samples,
                    min_variants=min_variants,
                    test_projects=test_projects)
# Out:
# starting pool creation with:
#    *** 100 NEGATIVE samples per pool
#    *** 4 VARIANTS including anchor
#    *** PROJECTS: ['zlib_similar_functions.json', 'unrar_similar_functions.json']
# added a fct pool
# processed 0 fcts
# added a fct pool
# processed 1 fcts
# added a fct pool
# processed 2 fcts
# added a fct pool
# processed 3 fcts
# added a fct pool
# processed 4 fcts
# added a fct pool
# processed 5 fcts
# added a fct pool
# processed 6 fcts
# added a fct pool
# processed 7 fcts
# added a fct pool
# processed 8 fcts
# added a fct pool
# processed 9 fcts
# added a fct pool
# processed 10 fcts
# added a fct pool
# processed 11 fcts
# added a fct pool
# processed 12 fcts
# added a fct pool
# processed 13 fcts
# added a fct pool
# processed 14 fcts
# added a fct pool
# processed 15 fcts
# added a fct pool
# processed 16 fcts
# added a fct pool
# processed 17 fcts
# added a fct pool
# processed 18 fcts
# added a fct pool
# processed 19 fcts
# added a fct pool
# processed 20 fcts
# added a fct pool
# processed 21 fcts
# added a fct pool
# processed 22 fcts
# added a fct pool
# processed 23 fcts
# added a fct pool
# processed 24 fcts
# added a fct pool
# processed 25 fcts
# added a fct pool
# processed 26 fcts
# added a fct pool
# processed 27 fcts
# added a fct pool
# processed 28 fcts
# added a fct pool
# processed 29 fcts
# added a fct pool
# processed 30 fcts
# added a fct pool
# processed 31 fcts
# added a fct pool
# processed 32 fcts
# added a fct pool
# processed 33 fcts
# added a fct pool
# processed 34 fcts
# added a fct pool
# processed 35 fcts
# added a fct pool
# processed 36 fcts
# added a fct pool
# processed 37 fcts
# added a fct pool
# processed 38 fcts
# added a fct pool
# processed 39 fcts
# added a fct pool
# processed 40 fcts
# added a fct pool
# processed 41 fcts
# added a fct pool
# processed 42 fcts
# added a fct pool
# processed 43 fcts
# added a fct pool
# processed 44 fcts
# added a fct pool
# processed 45 fcts
# added a fct pool
# processed 46 fcts
# added a fct pool
# processed 47 fcts
# added a fct pool
# processed 48 fcts
# added a fct pool
# processed 49 fcts
# added a fct pool
# processed 50 fcts
# added a fct pool
# processed 51 fcts
# added a fct pool
# processed 52 fcts
# added a fct pool
# processed 53 fcts
# added a fct pool
# processed 54 fcts
# added a fct pool
# processed 55 fcts
# added a fct pool
# processed 56 fcts
# added a fct pool
# processed 57 fcts
# added a fct pool
# processed 58 fcts
# added a fct pool
# processed 59 fcts
# added a fct pool
# processed 60 fcts
# added a fct pool
# processed 61 fcts
# added a fct pool
# processed 62 fcts
# added a fct pool
# processed 63 fcts
# added a fct pool
# processed 64 fcts
# added a fct pool
# processed 65 fcts
# added a fct pool
# processed 66 fcts
# added a fct pool
# processed 67 fcts
# added a fct pool
# processed 68 fcts
# added a fct pool
# processed 69 fcts
# added a fct pool
# processed 70 fcts
# added a fct pool
# processed 71 fcts
# added a fct pool
# processed 72 fcts
# added a fct pool
# processed 73 fcts
# added a fct pool
# processed 74 fcts
# added a fct pool
# processed 75 fcts
# added a fct pool
# processed 76 fcts
# added a fct pool
# processed 77 fcts
# added a fct pool
# processed 78 fcts
# added a fct pool
# processed 79 fcts
# added a fct pool
# processed 80 fcts
# added a fct pool
# processed 81 fcts
# added a fct pool
# processed 82 fcts
# added a fct pool
# processed 83 fcts
# added a fct pool
# processed 84 fcts
# added a fct pool
# processed 85 fcts
# added a fct pool
# processed 86 fcts
# added a fct pool
# processed 87 fcts
# added a fct pool
# processed 88 fcts
# added a fct pool
# processed 89 fcts
# added a fct pool
# processed 90 fcts
# added a fct pool
# processed 91 fcts
# added a fct pool
# processed 92 fcts
# added a fct pool
# processed 93 fcts
# added a fct pool
# processed 94 fcts
# added a fct pool
# processed 95 fcts
# added a fct pool
# processed 96 fcts
# added a fct pool
# processed 97 fcts
# added a fct pool
# processed 98 fcts
# added a fct pool
# processed 99 fcts
# added a fct pool
# processed 100 fcts
# added a fct pool
# processed 101 fcts
# added a fct pool
# processed 102 fcts
# added a fct pool
# processed 103 fcts
# added a fct pool
# processed 104 fcts
# added a fct pool
# processed 105 fcts
# added a fct pool
# processed 106 fcts
# added a fct pool
# processed 107 fcts
# added a fct pool
# processed 108 fcts
# added a fct pool
# processed 109 fcts
# added a fct pool
# processed 110 fcts
# added a fct pool
# processed 111 fcts
# added a fct pool
# processed 112 fcts
# added a fct pool
# processed 113 fcts
# added a fct pool
# processed 114 fcts
# added a fct pool
# processed 115 fcts
# added a fct pool
# processed 116 fcts
# added a fct pool
# processed 117 fcts
# added a fct pool
# processed 118 fcts
# added a fct pool
# processed 119 fcts
# added a fct pool
# processed 120 fcts
# added a fct pool
# processed 121 fcts
# added a fct pool
# processed 122 fcts
# added a fct pool
# processed 123 fcts
# added a fct pool
# processed 124 fcts
# added a fct pool
# processed 125 fcts
# added a fct pool
# processed 126 fcts
# added a fct pool
# processed 127 fcts
# added a fct pool
# processed 128 fcts
# added a fct pool
# processed 129 fcts
# added a fct pool
# processed 130 fcts
# added a fct pool
# processed 131 fcts
# added a fct pool
# processed 132 fcts
# added a fct pool
# processed 133 fcts
# added a fct pool
# processed 134 fcts
# added a fct pool
# processed 135 fcts
# added a fct pool
# processed 136 fcts
# added a fct pool
# processed 137 fcts
# added a fct pool
# processed 138 fcts
# added a fct pool
# processed 139 fcts
# added a fct pool
# processed 140 fcts
# added a fct pool
# processed 141 fcts
# added a fct pool
# processed 142 fcts
# added a fct pool
# processed 143 fcts
# added a fct pool
# processed 144 fcts
# added a fct pool
# processed 145 fcts
# added a fct pool
# processed 146 fcts
# added a fct pool
# processed 147 fcts
# added a fct pool
# processed 148 fcts
# added a fct pool
# processed 149 fcts
# added a fct pool
# processed 150 fcts
# added a fct pool
# processed 151 fcts
# added a fct pool
# processed 152 fcts
# added a fct pool
# processed 153 fcts
# added a fct pool
# processed 154 fcts
# added a fct pool
# processed 155 fcts
# added a fct pool
# processed 156 fcts
# added a fct pool
# processed 157 fcts
# added a fct pool
# processed 158 fcts
# added a fct pool
# processed 159 fcts
# added a fct pool
# processed 160 fcts
# added a fct pool
# processed 161 fcts
# added a fct pool
# processed 162 fcts
# added a fct pool
# processed 163 fcts
# added a fct pool
# processed 164 fcts
# added a fct pool
# processed 165 fcts
# added a fct pool
# processed 0 fcts
# added a fct pool
# processed 1 fcts
# added a fct pool
# processed 2 fcts
# added a fct pool
# processed 3 fcts
# added a fct pool
# processed 4 fcts
# added a fct pool
# processed 5 fcts
# added a fct pool
# processed 6 fcts
# added a fct pool
# processed 7 fcts
# added a fct pool
# processed 8 fcts
# added a fct pool
# processed 9 fcts
# added a fct pool
# processed 10 fcts
# added a fct pool
# processed 11 fcts
# added a fct pool
# processed 12 fcts
# added a fct pool
# processed 13 fcts
# added a fct pool
# processed 14 fcts
# added a fct pool
# processed 15 fcts
# added a fct pool
# processed 16 fcts
# added a fct pool
# processed 17 fcts
# added a fct pool
# processed 18 fcts
# added a fct pool
# processed 19 fcts
# added a fct pool
# processed 20 fcts
# added a fct pool
# processed 21 fcts
# added a fct pool
# processed 22 fcts
# added a fct pool
# processed 23 fcts
# added a fct pool
# processed 24 fcts
# added a fct pool
# processed 25 fcts
# added a fct pool
# processed 26 fcts
# added a fct pool
# processed 27 fcts
# added a fct pool
# processed 28 fcts
# added a fct pool
# processed 29 fcts
# added a fct pool
# processed 30 fcts
# added a fct pool
# processed 31 fcts
# added a fct pool
# processed 32 fcts
# added a fct pool
# processed 33 fcts
# added a fct pool
# processed 34 fcts
# added a fct pool
# processed 35 fcts
# added a fct pool
# processed 36 fcts
# added a fct pool
# processed 37 fcts
# added a fct pool
# processed 38 fcts
# added a fct pool
# processed 39 fcts
# added a fct pool
# processed 40 fcts
# added a fct pool
# processed 41 fcts
# added a fct pool
# processed 42 fcts
# added a fct pool
# processed 43 fcts
# added a fct pool
# processed 44 fcts
# added a fct pool
# processed 45 fcts
# added a fct pool
# processed 46 fcts
# added a fct pool
# processed 47 fcts
# added a fct pool
# processed 48 fcts
# added a fct pool
# processed 49 fcts
# added a fct pool
# processed 50 fcts
# added a fct pool
# processed 51 fcts
# added a fct pool
# processed 52 fcts
# added a fct pool
# processed 53 fcts
# added a fct pool
# processed 54 fcts
# added a fct pool
# processed 55 fcts
# added a fct pool
# processed 56 fcts
# added a fct pool
# processed 57 fcts
# added a fct pool
# processed 58 fcts
# added a fct pool
# processed 59 fcts
# added a fct pool
# processed 60 fcts
# added a fct pool
# processed 61 fcts
# added a fct pool
# processed 62 fcts
# added a fct pool
# processed 63 fcts
# added a fct pool
# processed 64 fcts
# added a fct pool
# processed 65 fcts
# added a fct pool
# processed 66 fcts
# added a fct pool
# processed 67 fcts
# added a fct pool
# processed 68 fcts
# added a fct pool
# processed 69 fcts
# added a fct pool
# processed 70 fcts
# added a fct pool
# processed 71 fcts
# added a fct pool
# processed 72 fcts
# added a fct pool
# processed 73 fcts
# added a fct pool
# processed 74 fcts
# added a fct pool
# processed 75 fcts
# added a fct pool
# processed 76 fcts
# added a fct pool
# processed 77 fcts
# added a fct pool
# processed 78 fcts
# added a fct pool
# processed 79 fcts
# added a fct pool
# processed 80 fcts
# added a fct pool
# processed 81 fcts
# added a fct pool
# processed 82 fcts
# added a fct pool
# processed 83 fcts
# added a fct pool
# processed 84 fcts
# added a fct pool
# processed 85 fcts
# added a fct pool
# processed 86 fcts
# added a fct pool
# processed 87 fcts
# added a fct pool
# processed 88 fcts
# added a fct pool
# processed 89 fcts
# added a fct pool
# processed 90 fcts
# added a fct pool
# processed 91 fcts
# added a fct pool
# processed 92 fcts
# added a fct pool
# processed 93 fcts
# added a fct pool
# processed 94 fcts
# added a fct pool
# processed 95 fcts
# added a fct pool
# processed 96 fcts
# added a fct pool
# processed 97 fcts
# added a fct pool
# processed 98 fcts
# added a fct pool
# processed 99 fcts
# added a fct pool
# processed 100 fcts
# added a fct pool
# processed 101 fcts
# added a fct pool
# processed 102 fcts
# added a fct pool
# processed 103 fcts
# added a fct pool
# processed 104 fcts
# added a fct pool
# processed 105 fcts
# added a fct pool
# processed 106 fcts
# added a fct pool
# processed 107 fcts
# added a fct pool
# processed 108 fcts
# added a fct pool
# processed 109 fcts
# added a fct pool
# processed 110 fcts
# added a fct pool
# processed 111 fcts
# added a fct pool
# processed 112 fcts
# added a fct pool
# processed 113 fcts
# added a fct pool
# processed 114 fcts
# added a fct pool
# processed 115 fcts
# added a fct pool
# processed 116 fcts
# added a fct pool
# processed 117 fcts
# added a fct pool
# processed 118 fcts
# added a fct pool
# processed 119 fcts
# added a fct pool
# processed 120 fcts
# added a fct pool
# processed 121 fcts
# added a fct pool
# processed 122 fcts
# added a fct pool
# processed 123 fcts
# added a fct pool
# processed 124 fcts
# added a fct pool
# processed 125 fcts
# added a fct pool
# processed 126 fcts
# added a fct pool
# processed 127 fcts
# added a fct pool
# processed 128 fcts
# added a fct pool
# processed 129 fcts
# added a fct pool
# processed 130 fcts
# added a fct pool
# processed 131 fcts
# added a fct pool
# processed 132 fcts
# added a fct pool
# processed 133 fcts
# added a fct pool
# processed 134 fcts
# added a fct pool
# processed 135 fcts
# added a fct pool
# processed 136 fcts
# added a fct pool
# processed 137 fcts
# added a fct pool
# processed 138 fcts
# added a fct pool
# processed 139 fcts
# added a fct pool
# processed 140 fcts
# added a fct pool
# processed 141 fcts
# added a fct pool
# processed 142 fcts
# added a fct pool
# processed 143 fcts
# added a fct pool
# processed 144 fcts
# added a fct pool
# processed 145 fcts
# added a fct pool
# processed 146 fcts
# added a fct pool
# processed 147 fcts
# added a fct pool
# processed 148 fcts
# added a fct pool
# processed 149 fcts
# added a fct pool
# processed 150 fcts
# added a fct pool
# processed 151 fcts
# added a fct pool
# processed 152 fcts
# added a fct pool
# processed 153 fcts
# added a fct pool
# processed 154 fcts
# added a fct pool
# processed 155 fcts
# added a fct pool
# processed 156 fcts
# added a fct pool
# processed 157 fcts
# added a fct pool
# processed 158 fcts
# added a fct pool
# processed 159 fcts
# added a fct pool
# processed 160 fcts
# added a fct pool
# processed 161 fcts
# added a fct pool
# processed 162 fcts
# added a fct pool
# processed 163 fcts
# added a fct pool
# processed 164 fcts
# added a fct pool
# processed 165 fcts
# added a fct pool
# processed 166 fcts
# added a fct pool
# processed 167 fcts
# added a fct pool
# processed 168 fcts
# added a fct pool
# processed 169 fcts
# added a fct pool
# processed 170 fcts
# added a fct pool
# processed 171 fcts
# added a fct pool
# processed 172 fcts
# added a fct pool
# processed 173 fcts
# added a fct pool
# processed 174 fcts
# added a fct pool
# processed 175 fcts
# added a fct pool
# processed 176 fcts
# added a fct pool
# processed 177 fcts
# added a fct pool
# processed 178 fcts
# added a fct pool
# processed 179 fcts
# added a fct pool
# processed 180 fcts
# added a fct pool
# processed 181 fcts
# added a fct pool
# processed 182 fcts
# added a fct pool
# processed 183 fcts
# added a fct pool
# processed 184 fcts
# added a fct pool
# processed 185 fcts
# added a fct pool
# processed 186 fcts
# added a fct pool
# processed 187 fcts
# added a fct pool
# processed 188 fcts
# added a fct pool
# processed 189 fcts
# added a fct pool
# processed 190 fcts
# added a fct pool
# processed 191 fcts
# added a fct pool
# processed 192 fcts
# added a fct pool
# processed 193 fcts
# added a fct pool
# processed 194 fcts
# added a fct pool
# processed 195 fcts
# added a fct pool
# processed 196 fcts
# added a fct pool
# processed 197 fcts
# added a fct pool
# processed 198 fcts
# added a fct pool
# processed 199 fcts
# added a fct pool
# processed 200 fcts
# added a fct pool
# processed 201 fcts
# added a fct pool
# processed 202 fcts
# added a fct pool
# processed 203 fcts
# added a fct pool
# processed 204 fcts
# added a fct pool
# processed 205 fcts
# added a fct pool
# processed 206 fcts
# added a fct pool
# processed 207 fcts
# added a fct pool
# processed 208 fcts
# added a fct pool
# processed 209 fcts
# added a fct pool
# processed 210 fcts
# added a fct pool
# processed 211 fcts
# added a fct pool
# processed 212 fcts
# added a fct pool
# processed 213 fcts
# added a fct pool
# processed 214 fcts
# added a fct pool
# processed 215 fcts
# added a fct pool
# processed 216 fcts
# added a fct pool
# processed 217 fcts
# added a fct pool
# processed 218 fcts
# added a fct pool
# processed 219 fcts
# added a fct pool
# processed 220 fcts
# added a fct pool
# processed 221 fcts
# added a fct pool
# processed 222 fcts
# added a fct pool
# processed 223 fcts
# added a fct pool
# processed 224 fcts
# added a fct pool
# processed 225 fcts
# added a fct pool
# processed 226 fcts
# added a fct pool
# processed 227 fcts
# added a fct pool
# processed 228 fcts
# added a fct pool
# processed 229 fcts
# added a fct pool
# processed 230 fcts
# added a fct pool
# processed 231 fcts
# added a fct pool
# processed 232 fcts
# added a fct pool
# processed 233 fcts
# added a fct pool
# processed 234 fcts
# added a fct pool
# processed 235 fcts
# added a fct pool
# processed 236 fcts
# added a fct pool
# processed 237 fcts
# added a fct pool
# processed 238 fcts
# added a fct pool
# processed 239 fcts
# added a fct pool
# processed 240 fcts
# added a fct pool
# processed 241 fcts
# added a fct pool
# processed 242 fcts
# added a fct pool
# processed 243 fcts
# added a fct pool
# processed 244 fcts
# added a fct pool
# processed 245 fcts
# added a fct pool
# processed 246 fcts
# added a fct pool
# processed 247 fcts
# added a fct pool
# processed 248 fcts
# added a fct pool
# processed 249 fcts
# added a fct pool
# processed 250 fcts
# added a fct pool
# processed 251 fcts
# added a fct pool
# processed 252 fcts
# added a fct pool
# processed 253 fcts
# added a fct pool
# processed 254 fcts
# added a fct pool
# processed 255 fcts
# added a fct pool
# processed 256 fcts
# added a fct pool
# processed 257 fcts
# added a fct pool
# processed 258 fcts
# added a fct pool
# processed 259 fcts
# added a fct pool
# processed 260 fcts
# added a fct pool
# processed 261 fcts
# added a fct pool
# processed 262 fcts
# added a fct pool
# processed 263 fcts
# added a fct pool
# processed 264 fcts
# added a fct pool
# processed 265 fcts
# added a fct pool
# processed 266 fcts
# added a fct pool
# processed 267 fcts
# added a fct pool
# processed 268 fcts
# added a fct pool
# processed 269 fcts
# added a fct pool
# processed 270 fcts
# added a fct pool
# processed 271 fcts
# added a fct pool
# processed 272 fcts
# added a fct pool
# processed 273 fcts
# added a fct pool
# processed 274 fcts
# added a fct pool
# processed 275 fcts
# added a fct pool
# processed 276 fcts
# added a fct pool
# processed 277 fcts
# added a fct pool
# processed 278 fcts
# added a fct pool
# processed 279 fcts
# added a fct pool
# processed 280 fcts
# added a fct pool
# processed 281 fcts
# added a fct pool
# processed 282 fcts
# added a fct pool
# processed 283 fcts
# added a fct pool
# processed 284 fcts
# added a fct pool
# processed 285 fcts
# added a fct pool
# processed 286 fcts
# added a fct pool
# processed 287 fcts
# added a fct pool
# processed 288 fcts
# added a fct pool
# processed 289 fcts
# added a fct pool
# processed 290 fcts
# added a fct pool
# processed 291 fcts
# added a fct pool
# processed 292 fcts
# added a fct pool
# processed 293 fcts
# added a fct pool
# processed 294 fcts
# added a fct pool
# processed 295 fcts
# added a fct pool
# processed 296 fcts
# added a fct pool
# processed 297 fcts
# added a fct pool
# processed 298 fcts
# added a fct pool
# processed 299 fcts
# added a fct pool
# processed 300 fcts
# added a fct pool
# processed 301 fcts
# added a fct pool
# processed 302 fcts
# added a fct pool
# processed 303 fcts
# added a fct pool
# processed 304 fcts
# added a fct pool
# processed 305 fcts
# added a fct pool
# processed 306 fcts
# added a fct pool
# processed 307 fcts
# added a fct pool
# processed 308 fcts
# added a fct pool
# processed 309 fcts
# added a fct pool
# processed 310 fcts
# added a fct pool
# processed 311 fcts
# added a fct pool
# processed 312 fcts
# added a fct pool
# processed 313 fcts
# added a fct pool
# processed 314 fcts
# added a fct pool
# processed 315 fcts
# added a fct pool
# processed 316 fcts
# added a fct pool
# processed 317 fcts
# added a fct pool
# processed 318 fcts
# added a fct pool
# processed 319 fcts
# added a fct pool
# processed 320 fcts
# added a fct pool
# processed 321 fcts
# added a fct pool
# processed 322 fcts
# added a fct pool
# processed 323 fcts
# added a fct pool
# processed 324 fcts
# added a fct pool
# processed 325 fcts
# added a fct pool
# processed 326 fcts
# added a fct pool
# processed 327 fcts
# added a fct pool
# processed 328 fcts
# added a fct pool
# processed 329 fcts
# added a fct pool
# processed 330 fcts
# added a fct pool
# processed 331 fcts
# added a fct pool
# processed 332 fcts
# added a fct pool
# processed 333 fcts
# added a fct pool
# processed 334 fcts
# added a fct pool
# processed 335 fcts
# added a fct pool
# processed 336 fcts
# added a fct pool
# processed 337 fcts
# added a fct pool
# processed 338 fcts
# added a fct pool
# processed 339 fcts
# added a fct pool
# processed 340 fcts
# added a fct pool
# processed 341 fcts
# added a fct pool
# processed 342 fcts
# added a fct pool
# processed 343 fcts
# added a fct pool
# processed 344 fcts
# added a fct pool
# processed 345 fcts
# added a fct pool
# processed 346 fcts
# added a fct pool
# processed 347 fcts
# added a fct pool
# processed 348 fcts
# added a fct pool
# processed 349 fcts
# added a fct pool
# processed 350 fcts
# added a fct pool
# processed 351 fcts
# added a fct pool
# processed 352 fcts
# added a fct pool
# processed 353 fcts
# added a fct pool
# processed 354 fcts
# added a fct pool
# processed 355 fcts
# added a fct pool
# processed 356 fcts
# added a fct pool
# processed 357 fcts
# added a fct pool
# processed 358 fcts
# added a fct pool
# processed 359 fcts
# added a fct pool
# processed 360 fcts
# added a fct pool
# processed 361 fcts
# added a fct pool
# processed 362 fcts
# added a fct pool
# processed 363 fcts
# added a fct pool
# processed 364 fcts
# added a fct pool
# processed 365 fcts
# added a fct pool
# processed 366 fcts
# added a fct pool
# processed 367 fcts
# added a fct pool
# processed 368 fcts
# added a fct pool
# processed 369 fcts
# added a fct pool
# processed 370 fcts
# added a fct pool
# processed 371 fcts
# added a fct pool
# processed 372 fcts
# added a fct pool
# processed 373 fcts
# added a fct pool
# processed 374 fcts
# added a fct pool
# processed 375 fcts
# added a fct pool
# processed 376 fcts
# added a fct pool
# processed 377 fcts
# added a fct pool
# processed 378 fcts
# added a fct pool
# processed 379 fcts
# added a fct pool
# processed 380 fcts
# added a fct pool
# processed 381 fcts
# added a fct pool
# processed 382 fcts
# added a fct pool
# processed 383 fcts
# added a fct pool
# processed 384 fcts
# added a fct pool
# processed 385 fcts
# added a fct pool
# processed 386 fcts
# added a fct pool
# processed 387 fcts
# added a fct pool
# processed 388 fcts
# added a fct pool
# processed 389 fcts
# added a fct pool
# processed 390 fcts
# added a fct pool
# processed 391 fcts
# added a fct pool
# processed 392 fcts
# added a fct pool
# processed 393 fcts
# added a fct pool
# processed 394 fcts
# added a fct pool
# processed 395 fcts
# added a fct pool
# processed 396 fcts
# added a fct pool
# processed 397 fcts
# added a fct pool
# processed 398 fcts
# added a fct pool
# processed 399 fcts
# added a fct pool
# processed 400 fcts
# added a fct pool
# processed 401 fcts
# added a fct pool
# processed 402 fcts
# added a fct pool
# processed 403 fcts
# added a fct pool
# processed 404 fcts
# added a fct pool
# processed 405 fcts
# added a fct pool
# processed 406 fcts
# added a fct pool
# processed 407 fcts
# added a fct pool
# processed 408 fcts
# added a fct pool
# processed 409 fcts
# added a fct pool
# processed 410 fcts
# added a fct pool
# processed 411 fcts
# added a fct pool
# processed 412 fcts
# added a fct pool
# processed 413 fcts
# added a fct pool
# processed 414 fcts
# added a fct pool
# processed 415 fcts
# added a fct pool
# processed 416 fcts
# added a fct pool
# processed 417 fcts
# added a fct pool
# processed 418 fcts
# added a fct pool
# processed 419 fcts
# added a fct pool
# processed 420 fcts
# added a fct pool
# processed 421 fcts
# added a fct pool
# processed 422 fcts
# added a fct pool
# processed 423 fcts
# added a fct pool
# processed 424 fcts
# added a fct pool
# processed 425 fcts
# added a fct pool
# processed 426 fcts
# added a fct pool
# processed 427 fcts
# added a fct pool
# processed 428 fcts
# added a fct pool
# processed 429 fcts
# added a fct pool
# processed 430 fcts
# added a fct pool
# processed 431 fcts
# added a fct pool
# processed 432 fcts
# added a fct pool
# processed 433 fcts
# added a fct pool
# processed 434 fcts
# added a fct pool
# processed 435 fcts
# added a fct pool
# processed 436 fcts
# added a fct pool
# processed 437 fcts
# added a fct pool
# processed 438 fcts
# added a fct pool
# processed 439 fcts
# added a fct pool
# processed 440 fcts
# added a fct pool
# processed 441 fcts
# added a fct pool
# processed 442 fcts
# added a fct pool
# processed 443 fcts
# added a fct pool
# processed 444 fcts
# added a fct pool
# processed 445 fcts
# added a fct pool
# processed 446 fcts
# added a fct pool
# processed 447 fcts
# added a fct pool
# processed 448 fcts
# added a fct pool
# processed 449 fcts
# added a fct pool
# processed 450 fcts
# added a fct pool
# processed 451 fcts
# added a fct pool
# processed 452 fcts
# added a fct pool
# processed 453 fcts
# added a fct pool
# processed 454 fcts
# added a fct pool
# processed 455 fcts
# added a fct pool
# processed 456 fcts
# added a fct pool
# processed 457 fcts
# added a fct pool
# processed 458 fcts
# added a fct pool
# processed 459 fcts
# added a fct pool
# processed 460 fcts
# added a fct pool
# processed 461 fcts
# added a fct pool
# processed 462 fcts
# added a fct pool
# processed 463 fcts
# added a fct pool
# processed 464 fcts
# added a fct pool
# processed 465 fcts
# added a fct pool
# processed 466 fcts
# added a fct pool
# processed 467 fcts
# added a fct pool
# processed 468 fcts
# added a fct pool
# processed 469 fcts
# added a fct pool
# processed 470 fcts
# added a fct pool
# processed 471 fcts
# added a fct pool
# processed 472 fcts
# added a fct pool
# processed 473 fcts
# added a fct pool
# processed 474 fcts
# added a fct pool
# processed 475 fcts
# added a fct pool
# processed 476 fcts
# added a fct pool
# processed 477 fcts
# added a fct pool
# processed 478 fcts
# added a fct pool
# processed 479 fcts
# added a fct pool
# processed 480 fcts
# added a fct pool
# processed 481 fcts
# added a fct pool
# processed 482 fcts
# added a fct pool
# processed 483 fcts
# added a fct pool
# processed 484 fcts
# added a fct pool
# processed 485 fcts
# added a fct pool
# processed 486 fcts
# added a fct pool
# processed 487 fcts
# added a fct pool
# processed 488 fcts
# added a fct pool
# processed 489 fcts
# added a fct pool
# processed 490 fcts
# added a fct pool
# processed 491 fcts
# added a fct pool
# processed 492 fcts
# added a fct pool
# processed 493 fcts
# added a fct pool
# processed 494 fcts
# added a fct pool
# processed 495 fcts
# added a fct pool
# processed 496 fcts
# added a fct pool
# processed 497 fcts
# added a fct pool
# processed 498 fcts
# added a fct pool
# processed 499 fcts
# added a fct pool
# processed 500 fcts
# added a fct pool
# processed 501 fcts
# added a fct pool
# processed 502 fcts
# added a fct pool
# processed 503 fcts
# added a fct pool
# processed 504 fcts
# added a fct pool
# processed 505 fcts
# added a fct pool
# processed 506 fcts
# added a fct pool
# processed 507 fcts
# added a fct pool
# processed 508 fcts
# added a fct pool
# processed 509 fcts
# added a fct pool
# processed 510 fcts
# added a fct pool
# processed 511 fcts
# added a fct pool
# processed 512 fcts
# added a fct pool
# processed 513 fcts
# added a fct pool
# processed 514 fcts
# added a fct pool
# processed 515 fcts
# added a fct pool
# processed 516 fcts
# added a fct pool
# processed 517 fcts
# added a fct pool
# processed 518 fcts
# added a fct pool
# processed 519 fcts
# added a fct pool
# processed 520 fcts
# added a fct pool
# processed 521 fcts
# added a fct pool
# processed 522 fcts
# added a fct pool
# processed 523 fcts
# added a fct pool
# processed 524 fcts
# added a fct pool
# processed 525 fcts
# added a fct pool
# processed 526 fcts
# added a fct pool
# processed 527 fcts
# added a fct pool
# processed 528 fcts
# added a fct pool
# processed 529 fcts
# added a fct pool
# processed 530 fcts
# added a fct pool
# processed 531 fcts
# added a fct pool
# processed 532 fcts
# added a fct pool
# processed 533 fcts
# added a fct pool
# processed 534 fcts
# added a fct pool
# processed 535 fcts
# added a fct pool
# processed 536 fcts
# added a fct pool
# processed 537 fcts
# added a fct pool
# processed 538 fcts
# added a fct pool
# processed 539 fcts
# added a fct pool
# processed 540 fcts
# added a fct pool
# processed 541 fcts
# added a fct pool
# processed 542 fcts
# added a fct pool
# processed 543 fcts
# added a fct pool
# processed 544 fcts
# added a fct pool
# processed 545 fcts
# added a fct pool
# processed 546 fcts
# added a fct pool
# processed 547 fcts
# added a fct pool
# processed 548 fcts
# added a fct pool
# processed 549 fcts
# added a fct pool
# processed 550 fcts
# added a fct pool
# processed 551 fcts
# added a fct pool
# processed 552 fcts
# added a fct pool
# processed 553 fcts
# added a fct pool
# processed 554 fcts
# added a fct pool
# processed 555 fcts
# added a fct pool
# processed 556 fcts
# added a fct pool
# processed 557 fcts
# added a fct pool
# processed 558 fcts
# added a fct pool
# processed 559 fcts
# added a fct pool
# processed 560 fcts
# added a fct pool
# processed 561 fcts
# added a fct pool
# processed 562 fcts
# added a fct pool
# processed 563 fcts
# added a fct pool
# processed 564 fcts
# added a fct pool
# processed 565 fcts
# added a fct pool
# processed 566 fcts
# added a fct pool
# processed 567 fcts
# added a fct pool
# processed 568 fcts
# added a fct pool
# processed 569 fcts
# added a fct pool
# processed 570 fcts
# added a fct pool
# processed 571 fcts
# added a fct pool
# processed 572 fcts
# added a fct pool
# processed 573 fcts
# added a fct pool
# processed 574 fcts
# added a fct pool
# processed 575 fcts
# added a fct pool
# processed 576 fcts
# added a fct pool
# processed 577 fcts
# added a fct pool
# processed 578 fcts
# added a fct pool
# processed 579 fcts
# added a fct pool
# processed 580 fcts
# added a fct pool
# processed 581 fcts
# added a fct pool
# processed 582 fcts
# added a fct pool
# processed 583 fcts
# added a fct pool
# processed 584 fcts
# added a fct pool
# processed 585 fcts
# added a fct pool
# processed 586 fcts
# added a fct pool
# processed 587 fcts
# added a fct pool
# processed 588 fcts
# added a fct pool
# processed 589 fcts
# added a fct pool
# processed 590 fcts
# added a fct pool
# processed 591 fcts
# added a fct pool
# processed 592 fcts
# added a fct pool
# processed 593 fcts
# added a fct pool
# processed 594 fcts
# added a fct pool
# processed 595 fcts
# added a fct pool
# processed 596 fcts
# added a fct pool
# processed 597 fcts
# added a fct pool
# processed 598 fcts
# added a fct pool
# processed 599 fcts
# added a fct pool
# processed 600 fcts
# added a fct pool
# processed 601 fcts
# added a fct pool
# processed 602 fcts
# added a fct pool
# processed 603 fcts
# added a fct pool
# processed 604 fcts
# added a fct pool
# processed 605 fcts
# added a fct pool
# processed 606 fcts
# added a fct pool
# processed 607 fcts
# added a fct pool
# processed 608 fcts
# added a fct pool
# processed 609 fcts
# added a fct pool
# processed 610 fcts
# added a fct pool
# processed 611 fcts
# added a fct pool
# processed 612 fcts
# added a fct pool
# processed 613 fcts
# added a fct pool
# processed 614 fcts
# added a fct pool
# processed 615 fcts
# added a fct pool
# processed 616 fcts
# added a fct pool
# processed 617 fcts
# added a fct pool
# processed 618 fcts
# added a fct pool
# processed 619 fcts
# added a fct pool
# processed 620 fcts
# added a fct pool
# processed 621 fcts
# added a fct pool
# processed 622 fcts
# added a fct pool
# processed 623 fcts
# added a fct pool
# processed 624 fcts
# added a fct pool
# processed 625 fcts
# added a fct pool
# processed 626 fcts
# added a fct pool
# processed 627 fcts
# added a fct pool
# processed 628 fcts
# added a fct pool
# processed 629 fcts
# added a fct pool
# processed 630 fcts
# added a fct pool
# processed 631 fcts
# added a fct pool
# processed 632 fcts
# added a fct pool
# processed 633 fcts
# added a fct pool
# processed 634 fcts
# added a fct pool
# processed 635 fcts
# added a fct pool
# processed 636 fcts
# added a fct pool
# processed 637 fcts
# added a fct pool
# processed 638 fcts
# added a fct pool
# processed 639 fcts
# added a fct pool
# processed 640 fcts
# added a fct pool
# processed 641 fcts
# added a fct pool
# processed 642 fcts
# added a fct pool
# processed 643 fcts
# added a fct pool
# processed 644 fcts
# added a fct pool
# processed 645 fcts
# added a fct pool
# processed 646 fcts
# added a fct pool
# processed 647 fcts
# added a fct pool
# processed 648 fcts
# added a fct pool
# processed 649 fcts
# added a fct pool
# processed 650 fcts
# added a fct pool
# processed 651 fcts
# added a fct pool
# processed 652 fcts
# added a fct pool
# processed 653 fcts
# added a fct pool
# processed 654 fcts
# added a fct pool
# processed 655 fcts
# added a fct pool
# processed 656 fcts
# added a fct pool
# processed 657 fcts
# added a fct pool
# processed 658 fcts
# added a fct pool
# processed 659 fcts
# added a fct pool
# processed 660 fcts
# added a fct pool
# processed 661 fcts
# added a fct pool
# processed 662 fcts
# added a fct pool
# processed 663 fcts
# added a fct pool
# processed 664 fcts
# added a fct pool
# processed 665 fcts
# added a fct pool
# processed 666 fcts
# added a fct pool
# processed 667 fcts
# added a fct pool
# processed 668 fcts
# added a fct pool
# processed 669 fcts
# added a fct pool
# processed 670 fcts
# added a fct pool
# processed 671 fcts
# added a fct pool
# processed 672 fcts
# added a fct pool
# processed 673 fcts
# added a fct pool
# processed 674 fcts
# added a fct pool
# processed 675 fcts
# added a fct pool
# processed 676 fcts
# added a fct pool
# processed 677 fcts
# added a fct pool
# processed 678 fcts
# added a fct pool
# processed 679 fcts
# added a fct pool
# processed 680 fcts
# added a fct pool
# processed 681 fcts
# added a fct pool
# processed 682 fcts
# added a fct pool
# processed 683 fcts
# added a fct pool
# processed 684 fcts
# added a fct pool
# processed 685 fcts
# added a fct pool
# processed 686 fcts
# added a fct pool
# processed 687 fcts
# added a fct pool
# processed 688 fcts
# added a fct pool
# processed 689 fcts
# added a fct pool
# processed 690 fcts
# added a fct pool
# processed 691 fcts
# added a fct pool
# processed 692 fcts
# added a fct pool
# processed 693 fcts
# added a fct pool
# processed 694 fcts
# added a fct pool
# processed 695 fcts
# added a fct pool
# processed 696 fcts
# added a fct pool
# processed 697 fcts
# added a fct pool
# processed 698 fcts
# added a fct pool
# processed 699 fcts
# added a fct pool
# processed 700 fcts
# added a fct pool
# processed 701 fcts
# added a fct pool
# processed 702 fcts
# added a fct pool
# processed 703 fcts
# added a fct pool
# processed 704 fcts
# added a fct pool
# processed 705 fcts
# added a fct pool
# processed 706 fcts
# added a fct pool
# processed 707 fcts
# added a fct pool
# processed 708 fcts
# added a fct pool
# processed 709 fcts
# added a fct pool
# processed 710 fcts
# added a fct pool
# processed 711 fcts
# added a fct pool
# processed 712 fcts
# added a fct pool
# processed 713 fcts
# added a fct pool
# processed 714 fcts
# added a fct pool
# processed 715 fcts
# added a fct pool
# processed 716 fcts
# added a fct pool
# processed 717 fcts
# added a fct pool
# processed 718 fcts
# added a fct pool
# processed 719 fcts
# added a fct pool
# processed 720 fcts
# added a fct pool
# processed 721 fcts
# added a fct pool
# processed 722 fcts
# added a fct pool
# processed 723 fcts
# added a fct pool
# processed 724 fcts
# added a fct pool
# processed 725 fcts
# added a fct pool
# processed 726 fcts
# added a fct pool
# processed 727 fcts
# added a fct pool
# processed 728 fcts
# added a fct pool
# processed 729 fcts
# added a fct pool
# processed 730 fcts
# added a fct pool
# processed 731 fcts
# added a fct pool
# processed 732 fcts
# added a fct pool
# processed 733 fcts
# added a fct pool
# processed 734 fcts
# added a fct pool
# processed 735 fcts
# added a fct pool
# processed 736 fcts
# added a fct pool
# processed 737 fcts
# added a fct pool
# processed 738 fcts
# added a fct pool
# processed 739 fcts
# added a fct pool
# processed 740 fcts
# added a fct pool
# processed 741 fcts
# added a fct pool
# processed 742 fcts
# added a fct pool
# processed 743 fcts
# added a fct pool
# processed 744 fcts
# added a fct pool
# processed 745 fcts
# added a fct pool
# processed 746 fcts
# added a fct pool
# processed 747 fcts
# added a fct pool
# processed 748 fcts
# added a fct pool
# processed 749 fcts
# added a fct pool
# processed 750 fcts
# added a fct pool
# processed 751 fcts
# added a fct pool
# processed 752 fcts
# added a fct pool
# processed 753 fcts
# added a fct pool
# processed 754 fcts
# added a fct pool
# processed 755 fcts
# added a fct pool
# processed 756 fcts
# added a fct pool
# processed 757 fcts
# added a fct pool
# processed 758 fcts
# added a fct pool
# processed 759 fcts
# added a fct pool
# processed 760 fcts
# added a fct pool
# processed 761 fcts
# added a fct pool
# processed 762 fcts
# added a fct pool
# processed 763 fcts
# added a fct pool
# processed 764 fcts
# added a fct pool
# processed 765 fcts
# added a fct pool
# processed 766 fcts
# added a fct pool
# processed 767 fcts
# added a fct pool
# processed 768 fcts
# added a fct pool
# processed 769 fcts
# added a fct pool
# processed 770 fcts
# added a fct pool
# processed 771 fcts
# added a fct pool
# processed 772 fcts
# added a fct pool
# processed 773 fcts
# added a fct pool
# processed 774 fcts
# added a fct pool
# processed 775 fcts
# added a fct pool
# processed 776 fcts
# added a fct pool
# processed 777 fcts
# added a fct pool
# processed 778 fcts
# added a fct pool
# processed 779 fcts
# added a fct pool
# processed 780 fcts
# added a fct pool
# processed 781 fcts
# added a fct pool
# processed 782 fcts
# added a fct pool
# processed 783 fcts
# added a fct pool
# processed 784 fcts
# added a fct pool
# processed 785 fcts
# added a fct pool
# processed 786 fcts
# added a fct pool
# processed 787 fcts
# added a fct pool
# processed 788 fcts
# added a fct pool
# processed 789 fcts
# added a fct pool
# processed 790 fcts
# added a fct pool
# processed 791 fcts
# added a fct pool
# processed 792 fcts
# added a fct pool
# processed 793 fcts
# added a fct pool
# processed 794 fcts
# added a fct pool
# processed 795 fcts
# added a fct pool
# processed 796 fcts
# added a fct pool
# processed 797 fcts
# added a fct pool
# processed 798 fcts
# added a fct pool
# processed 799 fcts
# added a fct pool
# processed 800 fcts
# added a fct pool
# processed 801 fcts
# added a fct pool
# processed 802 fcts
# added a fct pool
# processed 803 fcts
# added a fct pool
# processed 804 fcts
# added a fct pool
# processed 805 fcts
# added a fct pool
# processed 806 fcts
# added a fct pool
# processed 807 fcts
# added a fct pool
# processed 808 fcts
# added a fct pool
# processed 809 fcts
# added a fct pool
# processed 810 fcts
# added a fct pool
# processed 811 fcts
# added a fct pool
# processed 812 fcts
# added a fct pool
# processed 813 fcts
# added a fct pool
# processed 814 fcts
# added a fct pool
# processed 815 fcts
# added a fct pool
# processed 816 fcts
# added a fct pool
# processed 817 fcts
# added a fct pool
# processed 818 fcts
# added a fct pool
# processed 819 fcts
# added a fct pool
# processed 820 fcts
# added a fct pool
# processed 821 fcts
# added a fct pool
# processed 822 fcts
# added a fct pool
# processed 823 fcts
# built 990 fct pools
